# %%
# !pip install -qU \
  pinecone-client==3.1.0 \
  pinecone-datasets==0.7.0 \
  sentence-transformers==2.2.2 \
  pinecone-notebooks==0.1.1

# %%
import os

print("Check environment\n---------------------")

pinecone_api_key = os.environ.get('PINECONE_API_KEY') or ""

print("pinecone_api_key:", pinecone_api_key)
# Out:
# Check environment
# ---------------------
# pinecone_api_key: d4b84512-ffa0-41ab-b149-d7db7637c9e2

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
df_images = pd.read_csv('images/images.csv')

# %%
import json
import pandas as pd

# Path to your JSON file
file_path = 'listings/listings_0.json'

# Lists to store image IDs and item names
image_ids = []
img_paths = []
item_names = []
feature_list = []
# other_images_ids = []

count = 0
# Open and read the file line by line
with open(file_path, 'r') as file:
    for line in file:
        one_entry_img_paths = []
        # Parse the JSON data from each line
        json_data = json.loads(line)
        if 'main_image_id' in json_data and 'item_name' in json_data:
            if json_data['item_name'][0]['language_tag'].startswith('en'):
                image_id = json_data['main_image_id']
                item_name = json_data['item_name'][0]['value']
                image_path = df_images[df_images['image_id'] == image_id]['path'].tolist()[0]
                one_entry_img_paths.append(image_path)
                if 'other_image_id' in json_data:
                    other_ids = json_data['other_image_id']
                    for ids in other_ids:
                        im_path = df_images[df_images['image_id'] == image_id]['path'].tolist()[0]
                        one_entry_img_paths.append(im_path)
                else:
                    other_ids = ''
                # Collect bullet points if they exist and are in English
                if 'bullet_point' in json_data:
                    bullets = [bp['value'] for bp in json_data['bullet_point'] if bp['language_tag'].startswith('en')]
                    bullet_text = '; '.join(bullets)  # Join all bullet points into a single string
                else:
                    bullet_text = ''
                
                img_paths.append(one_entry_img_paths)
                image_ids.append(image_id)
                item_names.append(item_name)
                feature_list.append(bullet_text)
                # other_images_ids.append(other_ids)
                count+=1
                if count == 50:
                    break

# %%
metadata = {
    'primary_image_id': image_ids,
    'image_path': img_paths,
    'item_name': item_names,
    'features': feature_list
}

# %%
count_id = 0
main_json = {}

for i, p_id in enumerate(metadata['primary_image_id']):

    # pid_to_int = {}
    single_entry = {'item_name': metadata['item_name'][i], 'features': metadata['features'][i], 'image_paths': []}

    for path in metadata['image_path'][i]:

        single_entry['image_paths'].append(path)

    main_json[p_id] = single_entry

# %%
main_json
# Out:
# {'81NP7qh2L6L': {'item_name': 'AmazonBasics PETG 3D Printer Filament, 1.75mm, 1 kg Spool 1.75mm AMG10528516-10',
#   'features': "3D printer filament with 1.75mm diameter + / - .05mm; designed to fit most common 3D printers (check spool size for compatibility); Translucent Yellow; 1 kg spool; Made of PETG plastic, known for its ease of use (like PLA) and durable strength (like ABS); no heating bed needed; offers easy bed adhesion, stiffness, and a glossy finish; Spool's built-in gauge shows percentage of material remaining and approximate length remaining; Engineered to reduce jamming; resealable storage bag included to protect filament between use; Measures 9.2 by 8.3 by 3 inches (LxWxH); weighs 2.2 pounds; backed by an AmazonBasics 1-year limited warranty",
#   'image_paths': ['66/665cc994.jpg', '66/665cc994.jpg', '66/665cc994.jpg']},
#  '61Rp4qOih9L': {'item_name': 'Stone & Beam Stone Brown Swatch, 25020039-01',
#   'features': '',
#   'image_paths': ['b4/b4f9d0cc.jpg']},
#  '714CmIfKIYL': {'item_name': "The Fix Amazon Brand Women's French Floral Embroidery Slide Slip-on Loafer, Havana Tan, 6.5 B US",
#   'features': 'Embroidered flowers bloom against understated tan suede in this backless loafer with apron toe and cross strap.; Minimalist heel',
#   'image_paths': ['2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg',
#    '2b/2b1c2516.jpg']},
#  '81+4dBN1jsL': {'item_name': 'Amazon Brand - Solimo Designer Autumn Girl 3D Printed Hard Back Case Mobile Cover for Mi Redmi Go',
#   'features': 'Snug fit for Mi Redmi Go, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Mi Redmi Go; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['9d/9dfccb37.jpg',
#    '9d/9dfccb37.jpg',
#    '9d/9dfccb37.jpg',
#    '9d/9dfccb37.jpg',
#    '9d/9dfccb37.jpg']},
#  '61LWeNhjZ9L': {'item_name': 'Amazon Brand - Solimo Designer Butterflies Printed Hard Back Case Mobile Cover for Xiaomi Redmi Y2 (D187)',
#   'features': 'Snug fit for Xiaomi Redmi Y2, with perfect cutouts for volume buttons, audio and charging ports; Stylish design and appearance, express your unique personality; High Resolution UV light-ion 3D Embossed Printing for extraordinary quality and clarity. Printed using high end advanced Japanese machines. Your get our quality promise and design excellence; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Protects phone from scratches, fingerprints and sweat; Easy to put and take off; None',
#   'image_paths': ['9f/9f903271.jpg',
#    '9f/9f903271.jpg',
#    '9f/9f903271.jpg',
#    '9f/9f903271.jpg',
#    '9f/9f903271.jpg',
#    '9f/9f903271.jpg']},
#  '61izEZdhlaL': {'item_name': 'AmazonBasics Serene 16-Piece Old Fashioned and Coolers Glass Drinkware Set',
#   'features': 'Lead-free glass: made of crystal-clear, lead-free glass for stunning clarity; keeps its shine through many washings; beautifully showcases beverages and adds a touch of glamour to any gathering; Versatile: suitable for special occasions and everyday use; ideal for serving liquor, mixed drinks, and non-alcoholic beverages, like freshly squeezed lemonade, iced tea, juice, water, soda, and more; Chic style and easy care: heavy sham for extra stability; squared base transitions into a circular rim for eye-catching aesthetics; dishwasher-safe for convenient cleaning; Includes: (8) 16-ounce cooler glasses and (8) 13-ounce DOF glasses; made in the USA; Dimensions: cooler glass measures 6.2 inches high by 3.1 inches wide with a 2.9-inch base; DOF glass measures 4 inches high by 3.6 inches wide with a 3.3-inch base',
#   'image_paths': ['07/075e5d67.jpg',
#    '07/075e5d67.jpg',
#    '07/075e5d67.jpg',
#    '07/075e5d67.jpg']},
#  '71tgJqobw6L': {'item_name': 'Amazon Brand - Solimo Designer Butterflies Neon Light 3D Printed Hard Back Case Mobile Cover for Vivo Y81i',
#   'features': 'Snug fit for Vivo Y81i, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Vivo Y81i; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['77/77412532.jpg',
#    '77/77412532.jpg',
#    '77/77412532.jpg',
#    '77/77412532.jpg',
#    '77/77412532.jpg']},
#  '71E62qS--6L': {'item_name': 'UMI by Amazon 6 PCS Stretch Dining Chair Covers Melange Velvet Removable Chair Protector Elastic Slipcovers Turquoise',
#   'features': 'Product Detail: Package include 6 pieces of chair.The Umi high elastic couch covers for chair is flexible, soft, and slip resistant for long-term comfort. Craft from 97% Polyster, 3% Spandex.; With the unique shiny suede umi velvet chair will make your normal and old chairs brand new. Ideal for chairs that measure between 16"to 23" back high and 15" to 18" back width. Seat length and width from 16" to 22" and seat high of 1" to 4"; Our dining room chair Slipcovers could help protect your furniture from daily tear, spills, stains and so on. We are confident in the quality of our products.; Chairs with Umi chair covers will be a good addition fot kitchen, bedroom, living room decoration, office or hotel, wedding, party, celebrations, ceremonies, etc.; Care Instructions: Machine Washable with cold water. Tumble Dry Low. Do Not Bleach Nor Ironing. Do not hesitate to contact us if there’s any issue with your order or product',
#   'image_paths': ['73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg',
#    '73/736f202c.jpg']},
#  '71Ajg8gQEoL': {'item_name': 'Amazon Brand - Solimo Designer Autumn Girl UV Printed Soft Back Case Mobile Cover for Karbonn Aura Power 4G Plus',
#   'features': 'Snug fit for Karbonn Aura Power 4G Plus, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Karbonn Aura Power 4G Plus; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['5f/5f0c12f2.jpg', '5f/5f0c12f2.jpg', '5f/5f0c12f2.jpg']},
#  '71z2XJ0DW2L': {'item_name': 'Amazon Brand - Solimo Designer Water Drop On Glass UV Printed Soft Back Case Mobile Cover for Samsung Galaxy A70s',
#   'features': 'Snug fit for Samsung Galaxy A70s, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Samsung Galaxy A70s; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; None',
#   'image_paths': ['8b/8b519b9b.jpg', '8b/8b519b9b.jpg', '8b/8b519b9b.jpg']},
#  '81RNHjN1X5L': {'item_name': 'Amazon Brand - Solimo Designer Cactus 3D Printed Hard Back Case Mobile Cover for Motorola Moto G4 Plus',
#   'features': '3D Printed Hard Back Case Mobile Cover for Motorola Moto G4 Plus; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['a1/a1774265.jpg',
#    'a1/a1774265.jpg',
#    'a1/a1774265.jpg',
#    'a1/a1774265.jpg',
#    'a1/a1774265.jpg']},
#  '61Q0baX067L': {'item_name': 'Amazon Brand - Solimo Designer Kitty Printed Hard Back Case Mobile Cover for Samsung Galaxy M10 (D1211)',
#   'features': 'Snug fit for Samsung Galaxy M10, with perfect cutouts for volume buttons, audio & charging ports; Stylish design and appearance, express your unique personality; High Resolution UV light-ion 3D Embossed Printing for extraordinary quality and clarity. Printed using high end advanced Japanese machines. Your get our quality promise and design excellence; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Protects phone from scratches, fingerprints and sweat; Easy to put & take off; None',
#   'image_paths': ['9f/9f89869d.jpg',
#    '9f/9f89869d.jpg',
#    '9f/9f89869d.jpg',
#    '9f/9f89869d.jpg',
#    '9f/9f89869d.jpg',
#    '9f/9f89869d.jpg']},
#  '71aiNHh7MOL': {'item_name': 'Amazon Brand - Solimo Designer Colored Paris 3D Printed Hard Back Case Mobile Cover for Samsung Galaxy M40',
#   'features': 'Snug fit for Samsung Galaxy M40, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Samsung Galaxy M40; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['7a/7a46b66c.jpg',
#    '7a/7a46b66c.jpg',
#    '7a/7a46b66c.jpg',
#    '7a/7a46b66c.jpg',
#    '7a/7a46b66c.jpg']},
#  '71n4+cwHf0L': {'item_name': 'Amazon Brand - Solimo Designer Desert Plant 3D Printed Hard Back Case Mobile Cover for Huawei Honor 5c',
#   'features': '3D Printed Hard Back Case Mobile Cover for Huawei Honor 5c; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['29/2957b26e.jpg',
#    '29/2957b26e.jpg',
#    '29/2957b26e.jpg',
#    '29/2957b26e.jpg',
#    '29/2957b26e.jpg']},
#  '71I4fD2ZneL': {'item_name': 'Amazon Brand - Solimo Designer Photography UV Printed Soft Back Case Mobile Cover for Mi Redmi Y3',
#   'features': 'Snug fit for Mi Redmi Y3, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Mi Redmi Y3; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; None',
#   'image_paths': ['28/28019d8d.jpg', '28/28019d8d.jpg', '28/28019d8d.jpg']},
#  '71ynBbd33HL': {'item_name': 'Amazon Brand - Solimo Designer Floral Printed Hard Back Case Mobile Cover for Xiaomi Redmi Note 5 (D386)',
#   'features': 'Snug fit for Xiaomi Redmi Note 5, with perfect cutouts for volume buttons, audio & charging ports; Stylish design and appearance, express your unique personality; High Resolution UV light-ion 3D Embossed Printing for extraordinary quality and clarity. Printed using high end advanced Japanese machines. Your get our quality promise and design excellence; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Protects phone from scratches, fingerprints and sweat; Easy to put & take off; None',
#   'image_paths': ['55/55ed3324.jpg',
#    '55/55ed3324.jpg',
#    '55/55ed3324.jpg',
#    '55/55ed3324.jpg',
#    '55/55ed3324.jpg',
#    '55/55ed3324.jpg']},
#  '71NA-B-bFdL': {'item_name': 'Amazon Brand - Solimo Designer Horizontal Arrow Texture 3D Printed Hard Back Case Mobile Cover for Motorola Moto E 2nd Generation',
#   'features': '3D Printed Hard Back Case Mobile Cover for Motorola Moto E 2nd Generation; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['fd/fd693608.jpg',
#    'fd/fd693608.jpg',
#    'fd/fd693608.jpg',
#    'fd/fd693608.jpg',
#    'fd/fd693608.jpg']},
#  '810fadO2BML': {'item_name': 'Amazon Brand - Solimo Designer Foil Paper Texture 3D Printed Hard Back Case Mobile Cover for Vivo Y51L',
#   'features': '3D Printed Hard Back Case Mobile Cover for Vivo Y51L; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['64/64aa56cb.jpg']},
#  '61O+zPYa5AL': {'item_name': 'Amazon Brand - Solimo Designer Candle Light 3D Printed Hard Back Case Mobile Cover for Oppo F5',
#   'features': '3D Printed Hard Back Case Mobile Cover for Oppo F5; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['3f/3f6eb844.jpg',
#    '3f/3f6eb844.jpg',
#    '3f/3f6eb844.jpg',
#    '3f/3f6eb844.jpg',
#    '3f/3f6eb844.jpg']},
#  '71fT96mT39L': {'item_name': 'Amazon Brand - Solimo Designer Steam Train 3D Printed Hard Back Case Mobile Cover for Samsung Galaxy M21',
#   'features': 'Snug fit for Samsung Galaxy M21, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Samsung Galaxy M21; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['ea/ea5469c6.jpg',
#    'ea/ea5469c6.jpg',
#    'ea/ea5469c6.jpg',
#    'ea/ea5469c6.jpg',
#    'ea/ea5469c6.jpg']},
#  '71q5qvcwI7L': {'item_name': 'Amazon Brand - Solimo Designer Love Print On Cloth Pattern 3D Printed Hard Back Case Mobile Cover for Nokia 7.1',
#   'features': '3D Printed Hard Back Case Mobile Cover for Nokia 7.1; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['7d/7dc996dd.jpg',
#    '7d/7dc996dd.jpg',
#    '7d/7dc996dd.jpg',
#    '7d/7dc996dd.jpg',
#    '7d/7dc996dd.jpg']},
#  '61NxifiMbuL': {'item_name': 'Amazon Brand - Solimo Designer Dark Flowers Photography 3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi 1S',
#   'features': '3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi 1S; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['42/4213f453.jpg',
#    '42/4213f453.jpg',
#    '42/4213f453.jpg',
#    '42/4213f453.jpg',
#    '42/4213f453.jpg']},
#  '61XWVe-B-sL': {'item_name': 'Amazon Brand - Solimo Designer Black Pattern Alphabet-C 3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi 8A',
#   'features': 'Snug fit for Mobile, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Xiaomi Redmi 8A; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.No warranty',
#   'image_paths': ['ae/ae586045.jpg',
#    'ae/ae586045.jpg',
#    'ae/ae586045.jpg',
#    'ae/ae586045.jpg']},
#  '81n2LMvnU-L': {'item_name': 'Amazon Brand - Solimo Designer Orange Canvas 3D Printed Hard Back Case Mobile Cover for Nokia 6.1 Plus',
#   'features': '3D Printed Hard Back Case Mobile Cover for Nokia 6.1 Plus; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['eb/eb4a1f55.jpg',
#    'eb/eb4a1f55.jpg',
#    'eb/eb4a1f55.jpg',
#    'eb/eb4a1f55.jpg',
#    'eb/eb4a1f55.jpg']},
#  '61eajEqMf6L': {'item_name': 'Amazon Brand - Solimo Designer Never be Alone Printed Hard Back Case Mobile Cover for Apple iPhone XR (D1256)',
#   'features': 'Snug fit for Apple iPhone XR, with perfect cutouts for volume buttons, audio and charging ports; Stylish design and appearance, express your unique personality; High Resolution UV light-ion 3D Embossed Printing for extraordinary quality and clarity. Printed using high end advanced Japanese machines. Your get our quality promise and design excellence; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Protects phone from scratches, fingerprints and sweat; Easy to put and take off; None',
#   'image_paths': ['24/2470351d.jpg',
#    '24/2470351d.jpg',
#    '24/2470351d.jpg',
#    '24/2470351d.jpg',
#    '24/2470351d.jpg',
#    '24/2470351d.jpg']},
#  '71kE0ihplPL': {'item_name': "Stanton Men's Brown Loafers-8 UK (42 EU) (9 US) (FK/YT1893/BRW)",
#   'features': 'Outer Material: PU; Closure Type: Slip On; Toe Style: Round Toe; Warranty Type: Manufacturer; Warranty Description: 90 days',
#   'image_paths': ['cd/cd870277.jpg',
#    'cd/cd870277.jpg',
#    'cd/cd870277.jpg',
#    'cd/cd870277.jpg',
#    'cd/cd870277.jpg',
#    'cd/cd870277.jpg',
#    'cd/cd870277.jpg']},
#  '81fnogeiBfL': {'item_name': 'Amazon Brand - Solimo Designer Lion UV Printed Soft Back Case Mobile Cover for Huawei\xa0Honor\xa07A',
#   'features': 'Snug fit for Huawei\xa0Honor\xa07A, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Huawei\xa0Honor\xa07A; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.',
#   'image_paths': ['80/804ecc8d.jpg', '80/804ecc8d.jpg', '80/804ecc8d.jpg']},
#  '610jXVKNJpL': {'item_name': 'AmazonBasics Eastlake Coolers Glass Drinkware Set, 15-Ounce, Set of 6',
#   'features': 'Lead-free glass: made of crystal-clear, lead-free glass for stunning clarity; keeps its shine through many washings; beautifully showcases beverages and adds a touch of glamour to any gathering; Versatile: suitable for special occasions and everyday use; ideal for serving both mixed drinks and non-alcoholic beverages, like freshly squeezed lemonade, iced tea, water, soda, juice, and more; Contemporary style: sleek silhouette with gently curved sides and an exaggerated sham for extra stability and eye-catching allure; Easy care: dishwasher-safe for quick, convenient cleaning; made in the USA; Dimensions: measures 5.8 inches high by 3.2 inches wide with a 2.1-inch base',
#   'image_paths': ['ea/ea0c6da6.jpg',
#    'ea/ea0c6da6.jpg',
#    'ea/ea0c6da6.jpg',
#    'ea/ea0c6da6.jpg']},
#  '716zkGeKvyL': {'item_name': 'Amazon Brand - Solimo Designer Wooden Design 3D Printed Hard Back Case Mobile Cover for Coolpad Note 5',
#   'features': 'Snug fit for Mobile, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Coolpad Note 5; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; No warranty',
#   'image_paths': ['4d/4d59969e.jpg',
#    '4d/4d59969e.jpg',
#    '4d/4d59969e.jpg',
#    '4d/4d59969e.jpg']},
#  '71S0F2JJXEL': {'item_name': 'Amazon Brand - Solimo Designer Sparkle Girl Boss 3D Printed Hard Back Case Mobile Cover for Vivo Y69',
#   'features': '3D Printed Hard Back Case Mobile Cover for Vivo Y69; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['04/040353c9.jpg',
#    '04/040353c9.jpg',
#    '04/040353c9.jpg',
#    '04/040353c9.jpg',
#    '04/040353c9.jpg']},
#  '61OnkGVhMWL': {'item_name': 'Amazonbasics On-Ear Wireless Bluetooth Headphones with Microphone - Champagne',
#   'features': 'Wireless headphones with compatible with Bluetooth 5.0 devices; Listen to music, news, or podcasts; take calls with the built-in microphone; Quality speakers with ultra-soft polyurethane and foam earphones; keeps ears comfortably cushioned; Adjustable padded headband folds 90 degrees for easy, compact storage; Color: Champagne; Rechargeable with 20+ hours music playback time a 50% volume; up to 12 days standby time',
#   'image_paths': ['35/3595924e.jpg']},
#  '818R27QVJSL': {'item_name': "Nia & Nicole Women's Clutch (Navy Blue:: Mustard)",
#   'features': 'Other material navy blue:: mustard colored clutch; 11 centimeters height x 21.5 centimeters length x 3 centimeters width; Snap closure; 3 compartments and 2 pockets; 15 days domestic warranty against manufacturing defects; Clean with damp cloth, do not expose to extreme heat., do not expose to extreme heat; Closure Type:-magnetic snap; Product dimensions:-(21.5 length x 3 width x 11 Height) in cm; 3 compartment 2 pocket And 6 card slots; Pu Material Navy Blue::Mustard Color Wallet',
#   'image_paths': ['d1/d1f6a50a.jpg',
#    'd1/d1f6a50a.jpg',
#    'd1/d1f6a50a.jpg',
#    'd1/d1f6a50a.jpg',
#    'd1/d1f6a50a.jpg',
#    'd1/d1f6a50a.jpg']},
#  '81jPNIa-+1L': {'item_name': 'Amazon Brand - Solimo Designer Take It Easy 3D Printed Hard Back Case Mobile Cover for HTC One M8',
#   'features': '3D Printed Hard Back Case Mobile Cover for HTC One M8; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty; None',
#   'image_paths': ['81/81170d88.jpg',
#    '81/81170d88.jpg',
#    '81/81170d88.jpg',
#    '81/81170d88.jpg',
#    '81/81170d88.jpg']},
#  '71oFcjO2ZsL': {'item_name': 'Amazon Brand - Solimo Designer Water Drop On Glass 3D Printed Hard Back Case Mobile Cover for Samsung Z2',
#   'features': '3D Printed Hard Back Case Mobile Cover for Samsung Z2; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty; None',
#   'image_paths': ['a1/a1aaf4c0.jpg',
#    'a1/a1aaf4c0.jpg',
#    'a1/a1aaf4c0.jpg',
#    'a1/a1aaf4c0.jpg',
#    'a1/a1aaf4c0.jpg']},
#  '71S8jh9mayL': {'item_name': "find. Women's Felix-1w1-112 Brogue, Blue Navy, 7",
#   'features': '',
#   'image_paths': ['cb/cb728deb.jpg',
#    'cb/cb728deb.jpg',
#    'cb/cb728deb.jpg',
#    'cb/cb728deb.jpg',
#    'cb/cb728deb.jpg']},
#  '61uONZVpAEL': {'item_name': "Amazon Brand - 206 Collective Men's Pike Driving Slip-on Loafer, Black, 9.5 D US",
#   'features': 'Moccasin-style loafer featuring suede upper and wraparound lacing with metallic eyelets; Removable comfort insole',
#   'image_paths': ['14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg',
#    '14/14d129a0.jpg']},
#  '71pbhQgbcZL': {'item_name': 'Amazon Brand - Solimo Designer Ball Heart 3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi Y1 Lite',
#   'features': '3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi Y1 Lite; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty; None',
#   'image_paths': ['00/0055d71a.jpg',
#    '00/0055d71a.jpg',
#    '00/0055d71a.jpg',
#    '00/0055d71a.jpg',
#    '00/0055d71a.jpg']},
#  '81i4JjJs5RL': {'item_name': 'Amazon Brand - Solimo Designer Iron Impression 3D Printed Hard Back Case Mobile Cover for Lenovo A6600',
#   'features': '3D Printed Hard Back Case Mobile Cover for Lenovo A6600; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty; None',
#   'image_paths': ['45/454c2616.jpg',
#    '45/454c2616.jpg',
#    '45/454c2616.jpg',
#    '45/454c2616.jpg',
#    '45/454c2616.jpg']},
#  '814RXC4DgkL': {'item_name': "Amazon Brand - Symbol Men's Tan PU Formal Shoes - 9 UK (AZ-SY-437)",
#   'features': "Outer Material: Pu; Product Type: Men's Formal Shoes; Shoe Width: Regular; Closure Type: Lace-Up; Toe Style: Round Toe; Heel Type: Block Heel; Heel Height: 1 inches; Warranty Type: Manufacturer; Product warranty against manufacturing defects: 30 days; Care Instructions: Allow your pair of shoes to air and de-odorize at regular basis; Use Shoe bags to prevent any stains or mildew; Dust any dry dirt from the surface using a clean cloth; Do not use Polish or Shiner.",
#   'image_paths': ['f4/f4f31eec.jpg',
#    'f4/f4f31eec.jpg',
#    'f4/f4f31eec.jpg',
#    'f4/f4f31eec.jpg',
#    'f4/f4f31eec.jpg',
#    'f4/f4f31eec.jpg']},
#  '81oNfRT6ebL': {'item_name': '365 EVERYDAY VALUE Organic Light Cream, 1 PT',
#   'features': 'Brought to you by Whole Foods Market.\xa0 The packaging for this product has a fresh new look. During this transition, you may get the original packaging or the new packaging in your order, but the product and quality is staying exactly the same. Enjoy!; Ultra-Pasteurized.; Just Milk & Cream with No Added Gums.; From Cows Not Treated with rBST.; Certified USDA Organic. Certified Kosher.',
#   'image_paths': ['e7/e7983ec5.jpg',
#    'e7/e7983ec5.jpg',
#    'e7/e7983ec5.jpg',
#    'e7/e7983ec5.jpg',
#    'e7/e7983ec5.jpg',
#    'e7/e7983ec5.jpg']},
#  '71kGA2ndq+L': {'item_name': 'Amazon Brand - Solimo Designer Wax Color 3D Printed Hard Back Case Mobile Cover for Asus Zenfone Max Pro M1 ZB601KL',
#   'features': '3D Printed Hard Back Case Mobile Cover for Asus Zenfone Max Pro M1 ZB601KL; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['64/641ff5a1.jpg',
#    '64/641ff5a1.jpg',
#    '64/641ff5a1.jpg',
#    '64/641ff5a1.jpg',
#    '64/641ff5a1.jpg']},
#  '71+R8dguS-L': {'item_name': 'Amazon Brand - Solimo Designer Button Jeans Alphabet-X 3D Printed Hard Back Case Mobile Cover for Xiaomi Redmi 8A',
#   'features': 'Snug fit for Mobile, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Xiaomi Redmi 8A; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.No warranty',
#   'image_paths': ['e0/e038f87a.jpg',
#    'e0/e038f87a.jpg',
#    'e0/e038f87a.jpg',
#    'e0/e038f87a.jpg']},
#  '61fH9aTfMIL': {'item_name': "Amazon Essentials Women's Manny, Brown Tan, 38.5 EU",
#   'features': "Classic and versatile design for everyday use and an excellent fit; Refined loafer silhouette with hem and vamp detail; Soft faux leather upper with a non-abrasive edge; Genuine leather lining with 'Heel Cushion' comfort technology; suede lining for added comfort and breathability; Padded insole with 6mm high quality memory foam for superior cushioning and comfort; Synthetic leather sock with natural hand and feel; Ultra flexible, lightweight and durable TPR outsole with minimal heel and traction grip front",
#   'image_paths': ['05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg',
#    '05/051b1105.jpg']},
#  '71Qitt7H5gL': {'item_name': 'Amazon Brand - Solimo Designer Patternn 3D Printed Hard Back Case Mobile Cover for LG Stylus 3',
#   'features': '3D Printed Hard Back Case Mobile Cover for LG Stylus 3; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty; None',
#   'image_paths': ['65/65310b27.jpg',
#    '65/65310b27.jpg',
#    '65/65310b27.jpg',
#    '65/65310b27.jpg',
#    '65/65310b27.jpg']},
#  '91T4zCd6GhL': {'item_name': '365 EVERYDAY VALUE Chai Spice Cashews, 10 OZ',
#   'features': 'Brought to you by Whole Foods Market; Limited seasonal collection; Non GMO Verified',
#   'image_paths': ['dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg',
#    'dc/dcf40fb6.jpg']},
#  '61y3xfkEpeL': {'item_name': 'Amazon Brand - Solimo Designer Multicolor Cute Love Red Pattern Design Printed Soft Back Case Mobile Cover for Samsung Galaxy Note 10 Lite',
#   'features': 'Snug fit for Mobile, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with Samsung Galaxy Note 10 Lite; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports; Stylish design and appearance, express your unique personality; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface; No warranty; None',
#   'image_paths': ['0d/0d4cd1f0.jpg',
#    '0d/0d4cd1f0.jpg',
#    '0d/0d4cd1f0.jpg',
#    '0d/0d4cd1f0.jpg']},
#  '81HZcUs-M-L': {'item_name': 'Amazon Brand - Solimo Designer Color Mash 3D Printed Hard Back Case Mobile Cover for Sony Xperia C5 Ultra Dual',
#   'features': '3D Printed Hard Back Case Mobile Cover for Sony Xperia C5 Ultra Dual; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; Slim Hard Back Cover; No Warranty',
#   'image_paths': ['65/65811a98.jpg',
#    '65/65811a98.jpg',
#    '65/65811a98.jpg',
#    '65/65811a98.jpg',
#    '65/65811a98.jpg']},
#  '7197RZj+FhL': {'item_name': 'Amazon Brand - Solimo Designer Sleepy Kitten UV Printed Soft Back Case Mobile Cover for 10.or\xa0G',
#   'features': 'Snug fit for 10.or\xa0G, with perfect cut-outs for volume buttons, audio and charging ports; Compatible with 10.or\xa0G; Easy to put & take off with perfect cutouts for volume buttons, audio & charging ports.; Stylish design and appearance, express your unique personality.; Extreme precision design allows easy access to all buttons and ports while featuring raised bezel to life screen and camera off flat surface.; None',
#   'image_paths': ['f7/f773eeb4.jpg', 'f7/f773eeb4.jpg', 'f7/f773eeb4.jpg']},
#  '71cyz3P4DKL': {'item_name': "Amazon Brand - Symbol Men's Leather Formal Slip-on shoes/India (44 EU)(AZ-WS-126B)",
#   'features': "Outer Material: Leather; Product Type: Men's Formal Shoes; Shoe Width: Medium; Closure Type: Slip On; Toe Style: Closed Toe; Cushioned footbed for maximum comfort; Warranty Type: Manufacturer; Product warranty against manufacturing defects: 30 days; Care Instructions: Clean your shoes with leather cleaner or leather shampoo, and use a good quality brush to remove loose surface dirt; If your shoes are wet after cleaning, let them air-dry before your proceed with the next step; Dry shoes in room temperature only and never expose them to the sun; Heat from the sun will cause the leather to shrink, wrinkle, harden, dry, and crack.",
#   'image_paths': ['b6/b630bf31.jpg',
#    'b6/b630bf31.jpg',
#    'b6/b630bf31.jpg',
#    'b6/b630bf31.jpg']},
#  '71ASEq6croL': {'item_name': 'AmazonBasics Modern Euro Toilet Paper Holder - Satin Nickel',
#   'features': 'Satin Nickel finish; made from durable zinc alloy; Fixture Width: 7-inches (17.78 cm); Fixture Projection: 3.13 inches (7.95 cm); 11-Lbs (5kgs) max weight capacity; Includes mounting screws, mounting brackets and drywall anchors; installation requires 1/8-inch (3.17mm) slotted screwdriver (not included); Backed by an AmazonBasics limited 1-year warranty',
#   'image_paths': ['cd/cd2f33b3.jpg', 'cd/cd2f33b3.jpg', 'cd/cd2f33b3.jpg']}}

# %%
import json

# Specify the file name
filename = 'mainjson.json'

# Writing JSON data
with open(filename, 'w') as f:
    json.dump(main_json, f, indent=4)

# %%
count_id = 0

pid_to_int_id = {}
img_paths_to_int_id = {}
for i, pid in enumerate(main_json):

    for path in main_json[pid]['image_paths']:

        pid_to_int_id[count_id] = pid
        img_paths_to_int_id[count_id] = path

        count_id+=1

# %%
# Specify the file name
filename = 'pid_to_int_id.json'

# Writing JSON data
with open(filename, 'w') as f:
    json.dump(pid_to_int_id, f, indent=4)

# %%
# Specify the file name
filename = 'img_paths_to_int_id.json'

# Writing JSON data
with open(filename, 'w') as f:
    json.dump(img_paths_to_int_id, f, indent=4)

# %% [markdown]
# ## Resnet50 feature extractor

# %%
import pandas as pd
import torch
from torchvision import models, transforms
from PIL import Image
import numpy as np



# Pre-trained ResNet50 model setup
model = models.resnet50(pretrained=True)
model = torch.nn.Sequential(*(list(model.children())[:-1]))  # Remove the last layer
model.eval()  # Set the model to evaluation mode

# Image preprocessing
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Function to extract features
def extract_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = preprocess(image).unsqueeze(0)  # Add batch dimension
    with torch.no_grad():  # No need to compute gradients
        features = model(image)
    return features.flatten().numpy()
# Out:
# /home/athenaai/anaconda3/envs/pinecone2/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/athenaai/anaconda3/envs/pinecone2/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
int_id_to_embedding = {}
for int_id, img_path in img_paths_to_int_id.items():
    # embeddings = []
    # for img_path in img_paths:
    emb = extract_features('images/small/'+img_path)
    int_id_to_embedding[int_id] = emb

# %% [markdown]
# ## Pinecone Setup

# %%
from pinecone import ServerlessSpec, Pinecone

pc = Pinecone(api_key='d4b84512-ffa0-41ab-b149-d7db7637c9e2')

pc.list_indexes().names()
# Out:
# ['pd-listing']

# %%
pc.describe_index(name="pd-listing")
# Out:
# {'dimension': 2048,
#  'host': 'pd-listing-p3m338e.svc.aped-4627-b74a.pinecone.io',
#  'metric': 'euclidean',
#  'name': 'pd-listing',
#  'spec': {'serverless': {'cloud': 'aws', 'region': 'us-east-1'}},
#  'status': {'ready': True, 'state': 'Ready'}}

# %%
product_listing_index = pc.Index('pd-listing')

# %%
for int_id, emb in int_id_to_embedding.items():

    product_listing_index.upsert(
        vectors=[
            {
                "id": str(int_id), 
                "values": emb, 
                # "metadata": {"genre": "drama"}
            },
        ],
        namespace= "ns1"
    )

# %%
all_embeddings = []
for img_paths in metadata['image_path']:
    embeddings = []
    for img_path in img_paths:
        try:
            emb = extract_features('images/small/'+img_path)
            embeddings.append(emb)
        except Exception as e:
            print(f"Error processing image {img_path}: {e}")
            embeddings.append(np.nan)
    all_embeddings.append(embeddings)
