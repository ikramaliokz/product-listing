# %%
import os
import openai

# %%
print("Check environment\n---------------------")

pinecone_api_key = os.environ.get('PINECONE_API_KEY') or ""

print("pinecone_api_key:", pinecone_api_key)


# openai doesn't need to be initialized, but need to set api key
openai.api_key=os.environ.get("OPENAI_API_KEY")
# Out:
# Check environment
# ---------------------
# pinecone_api_key: f385511c-d71a-41c4-b148-2ab39def04b6

# %% [markdown]
# ## Load image data

# %%
import pandas as pd
df_images = pd.read_csv('product-listing-dataset/images/images.csv')

# %%
df_images.head()
# Out:
#       image_id  height  width             path
# 0  010-mllS7JL     106    106  14/14fe8812.jpg
# 1  01dkn0Gyx0L     122    122  da/daab0cad.jpg
# 2  01sUPg0387L     111    111  d2/d2daaae9.jpg
# 3  1168jc-5r1L     186    186  3a/3a4e88e6.jpg
# 4  11RUV5Fs65L      30    500  d9/d91ab9cf.jpg

# %% [markdown]
# ## generate a json to store tiltes, descrption and its attached images in a json

# %%
from tqdm import tqdm
def embed(docs: list[str], batch_size=100) -> list[list[float]]:
    doc_embeds = []
    # Process documents in batches
    for i in tqdm(range(0, len(docs), batch_size)):
        batch = docs[i:i + batch_size]
        res = openai.embeddings.create(
        input=batch,
        model="text-embedding-ada-002"
        )
        # Extract embeddings for each document in the batch
        batch_embeds = [r.embedding for r in res.data]
        doc_embeds.extend(batch_embeds)
    return doc_embeds

# %%
import json
import pandas as pd

# Path to your JSON file
# file
file_paths = ['product-listing-dataset/listings/listings_0.json','product-listing-dataset/listings/listings_1.json','product-listing-dataset/listings/listings_3.json']


count = 0
main_json = {}
for file_path in file_paths:
    # Open and read the file line by line
    with open(file_path, 'r') as file:
        for line in file:
            one_entry_img_paths = []
            # Parse the JSON data from each line
            json_data = json.loads(line)
            if 'main_image_id' in json_data and 'item_name' in json_data:
                if json_data['item_name'][0]['language_tag'].startswith('en'):
                    image_id = json_data['main_image_id']
                    item_name = json_data['item_name'][0]['value']
                    image_path = df_images[df_images['image_id'] == image_id]['path'].tolist()[0]
                    one_entry_img_paths.append(image_path)
                    if 'other_image_id' in json_data:
                        other_ids = json_data['other_image_id']
                        for ids in other_ids:
                            im_path = df_images[df_images['image_id'] == image_id]['path'].tolist()[0]
                            one_entry_img_paths.append(im_path)
                    else:
                        other_ids = ''
                    # Collect bullet points if they exist and are in English
                    if 'bullet_point' in json_data:
                        bullets = [bp['value'] for bp in json_data['bullet_point'] if bp['language_tag'].startswith('en')]
                        bullet_text = '; '.join(bullets)  # Join all bullet points into a single string
                    else:
                        bullet_text = ''


                    single_entry = {'item_name': item_name, 'features': bullet_text, 'image_paths': one_entry_img_paths}

                    main_json[count]=single_entry

                    count+=1


                    
                    # img_paths.append(one_entry_img_paths)
                    # image_ids.append(image_id)
                    # item_names.append(item_name)
                    # feature_list.append(bullet_text)
        #             # other_images_ids.append(other_ids)
        #             if count == 100:
        #                 break
        # break

# %%
texts = [main_json[item]['item_name'] + main_json[item]['features'] for item in main_json.keys()]

# %%
embeddings=embed(texts)
# Out:
# 100%|██████████| 200/200 [06:08<00:00,  1.84s/it]

# %%
for id,embedding in zip(main_json,embeddings):
    print(id, embedding)

# %%
for id,embedding in zip(main_json,embeddings):
    main_json[id]['text_embedding']=embedding

# %%
len(main_json)
# Out:
# 19924

# %%
import json

# Specify the file name
filename = 'updated_struct_jsons/titles-descrp-paths.json'

# Writing JSON data
with open(filename, 'w') as f:
    json.dump(main_json, f, indent=4)

# %% [markdown]
# ## create image_embedding

# %%
import pandas as pd
import torch
from torchvision import models, transforms
from PIL import Image
import numpy as np



# Pre-trained ResNet50 model setup
model = models.resnet50(pretrained=True)
model = torch.nn.Sequential(*(list(model.children())[:-1]))  # Remove the last layer
model.eval()  # Set the model to evaluation mode

# Image preprocessing
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Function to extract features
def extract_features(image_path):
    image = Image.open(image_path).convert('RGB')
    image = preprocess(image).unsqueeze(0)  # Add batch dimension
    with torch.no_grad():  # No need to compute gradients
        features = model(image)
    return features.flatten().numpy()

# %% [markdown]
# ## create a id mapping to images and its titles

# %%
count_id = 0

id_to_pid_image_pth_embed = {}
for pid in tqdm(main_json):

    for path in main_json[pid]['image_paths']:

        id_to_pid_image_pth_embed[count_id] = {'p_id':pid, 'image_pth': path}
        id_to_pid_image_pth_embed[count_id]['image_embedding'] = extract_features('product-listing-dataset/images/small/'+path)

        count_id+=1
# Out:
# 100%|██████████| 19924/19924 [57:58<00:00,  5.73it/s]

# %%
id_to_pid_image_pth_embed
# Out:
# {0: {'p_id': 0,
#   'image_pth': '66/665cc994.jpg',
#   'image_embedding': array([0.08097482, 0.4570974 , 0.05311731, ..., 0.91808164, 0.3820621 ,
#          0.22633062], dtype=float32)},
#  1: {'p_id': 0,
#   'image_pth': '66/665cc994.jpg',
#   'image_embedding': array([0.08097482, 0.4570974 , 0.05311731, ..., 0.91808164, 0.3820621 ,
#          0.22633062], dtype=float32)},
#  2: {'p_id': 0,
#   'image_pth': '66/665cc994.jpg',
#   'image_embedding': array([0.08097482, 0.4570974 , 0.05311731, ..., 0.91808164, 0.3820621 ,
#          0.22633062], dtype=float32)},
#  3: {'p_id': 1,
#   'image_pth': 'b4/b4f9d0cc.jpg',
#   'image_embedding': array([0.58037436, 0.        , 0.00552477, ..., 0.00571453, 0.02709544,
#          0.785745  ], dtype=float32)},
#  4: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  5: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  6: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  7: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  8: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  9: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  10: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  11: {'p_id': 2,
#   'image_pth': '2b/2b1c2516.jpg',
#   'image_embedding': array([0.2102012 , 0.3178227 , 0.34608513, ..., 0.4285842 , 2.1814303 ,
#          1.3671106 ], dtype=float32)},
#  12: {'p_id': 3,
#   'image_pth': '9d/9dfccb37.jpg',
#   'image_embedding': array([0.39763275, 0.45075008, 0.0107177 , ..., 0.02404609, 0.7361802 ,
#          0.1297667 ], dtype=float32)},
#  13: {'p_id': 3,
#   'image_pth': '9d/9dfccb37.jpg',
#   'image_embedding': array([0.39763275, 0.45075008, 0.0107177 , ..., 0.02404609, 0.7361802 ,
#          0.1297667 ], dtype=float32)},
#  14: {'p_id': 3,
#   'image_pth': '9d/9dfccb37.jpg',
#   'image_embedding': array([0.39763275, 0.45075008, 0.0107177 , ..., 0.02404609, 0.7361802 ,
#          0.1297667 ], dtype=float32)},
#  15: {'p_id': 3,
#   'image_pth': '9d/9dfccb37.jpg',
#   'image_embedding': array([0.39763275, 0.45075008, 0.0107177 , ..., 0.02404609, 0.7361802 ,
#          0.1297667 ], dtype=float32)},
#  16: {'p_id': 3,
#   'image_pth': '9d/9dfccb37.jpg',
#   'image_embedding': array([0.39763275, 0.45075008, 0.0107177 , ..., 0.02404609, 0.7361802 ,
#          0.1297667 ], dtype=float32)},
#  17: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  18: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  19: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  20: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  21: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  22: {'p_id': 4,
#   'image_pth': '9f/9f903271.jpg',
#   'image_embedding': array([0.51067334, 0.02112306, 0.80249274, ..., 0.04211167, 0.43339613,
#          0.1753116 ], dtype=float32)},
#  23: {'p_id': 5,
#   'image_pth': '07/075e5d67.jpg',
#   'image_embedding': array([2.493531  , 0.49645233, 0.34449437, ..., 0.08350471, 1.3328329 ,
#          1.6011883 ], dtype=float32)},
#  24: {'p_id': 5,
#   'image_pth': '07/075e5d67.jpg',
#   'image_embedding': array([2.493531  , 0.49645233, 0.34449437, ..., 0.08350471, 1.3328329 ,
#          1.6011883 ], dtype=float32)},
#  25: {'p_id': 5,
#   'image_pth': '07/075e5d67.jpg',
#   'image_embedding': array([2.493531  , 0.49645233, 0.34449437, ..., 0.08350471, 1.3328329 ,
#          1.6011883 ], dtype=float32)},
#  26: {'p_id': 5,
#   'image_pth': '07/075e5d67.jpg',
#   'image_embedding': array([2.493531  , 0.49645233, 0.34449437, ..., 0.08350471, 1.3328329 ,
#          1.6011883 ], dtype=float32)},
#  27: {'p_id': 6,
#   'image_pth': '77/77412532.jpg',
#   'image_embedding': array([0.5060349 , 0.00630237, 0.28638005, ..., 0.04574826, 0.5788571 ,
#          0.55101514], dtype=float32)},
#  28: {'p_id': 6,
#   'image_pth': '77/77412532.jpg',
#   'image_embedding': array([0.5060349 , 0.00630237, 0.28638005, ..., 0.04574826, 0.5788571 ,
#          0.55101514], dtype=float32)},
#  29: {'p_id': 6,
#   'image_pth': '77/77412532.jpg',
#   'image_embedding': array([0.5060349 , 0.00630237, 0.28638005, ..., 0.04574826, 0.5788571 ,
#          0.55101514], dtype=float32)},
#  30: {'p_id': 6,
#   'image_pth': '77/77412532.jpg',
#   'image_embedding': array([0.5060349 , 0.00630237, 0.28638005, ..., 0.04574826, 0.5788571 ,
#          0.55101514], dtype=float32)},
#  31: {'p_id': 6,
#   'image_pth': '77/77412532.jpg',
#   'image_embedding': array([0.5060349 , 0.00630237, 0.28638005, ..., 0.04574826, 0.5788571 ,
#          0.55101514], dtype=float32)},
#  32: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  33: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  34: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  35: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  36: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  37: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  38: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  39: {'p_id': 7,
#   'image_pth': '73/736f202c.jpg',
#   'image_embedding': array([0.31203213, 0.15989274, 0.46593753, ..., 0.21845244, 0.21198565,
#          0.15196846], dtype=float32)},
#  40: {'p_id': 8,
#   'image_pth': '5f/5f0c12f2.jpg',
#   'image_embedding': array([1.0888017 , 0.35240483, 0.09614067, ..., 0.05780099, 0.86660844,
#          0.05810933], dtype=float32)},
#  41: {'p_id': 8,
#   'image_pth': '5f/5f0c12f2.jpg',
#   'image_embedding': array([1.0888017 , 0.35240483, 0.09614067, ..., 0.05780099, 0.86660844,
#          0.05810933], dtype=float32)},
#  42: {'p_id': 8,
#   'image_pth': '5f/5f0c12f2.jpg',
#   'image_embedding': array([1.0888017 , 0.35240483, 0.09614067, ..., 0.05780099, 0.86660844,
#          0.05810933], dtype=float32)},
#  43: {'p_id': 9,
#   'image_pth': '8b/8b519b9b.jpg',
#   'image_embedding': array([1.0180242 , 0.31786218, 0.38887554, ..., 0.10129921, 0.5148062 ,
#          0.54703826], dtype=float32)},
#  44: {'p_id': 9,
#   'image_pth': '8b/8b519b9b.jpg',
#   'image_embedding': array([1.0180242 , 0.31786218, 0.38887554, ..., 0.10129921, 0.5148062 ,
#          0.54703826], dtype=float32)},
#  45: {'p_id': 9,
#   'image_pth': '8b/8b519b9b.jpg',
#   'image_embedding': array([1.0180242 , 0.31786218, 0.38887554, ..., 0.10129921, 0.5148062 ,
#          0.54703826], dtype=float32)},
#  46: {'p_id': 10,
#   'image_pth': 'a1/a1774265.jpg',
#   'image_embedding': array([1.6628547 , 0.23836657, 0.05972787, ..., 0.02589192, 1.2974807 ,
#          0.00297245], dtype=float32)},
#  47: {'p_id': 10,
#   'image_pth': 'a1/a1774265.jpg',
#   'image_embedding': array([1.6628547 , 0.23836657, 0.05972787, ..., 0.02589192, 1.2974807 ,
#          0.00297245], dtype=float32)},
#  48: {'p_id': 10,
#   'image_pth': 'a1/a1774265.jpg',
#   'image_embedding': array([1.6628547 , 0.23836657, 0.05972787, ..., 0.02589192, 1.2974807 ,
#          0.00297245], dtype=float32)},
#  49: {'p_id': 10,
#   'image_pth': 'a1/a1774265.jpg',
#   'image_embedding': array([1.6628547 , 0.23836657, 0.05972787, ..., 0.02589192, 1.2974807 ,
#          0.00297245], dtype=float32)},
#  50: {'p_id': 10,
#   'image_pth': 'a1/a1774265.jpg',
#   'image_embedding': array([1.6628547 , 0.23836657, 0.05972787, ..., 0.02589192, 1.2974807 ,
#          0.00297245], dtype=float32)},
#  51: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  52: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  53: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  54: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  55: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  56: {'p_id': 11,
#   'image_pth': '9f/9f89869d.jpg',
#   'image_embedding': array([0.5437128 , 0.06592627, 0.42776093, ..., 0.03243462, 0.15500669,
#          0.00603318], dtype=float32)},
#  57: {'p_id': 12,
#   'image_pth': '7a/7a46b66c.jpg',
#   'image_embedding': array([0.76471406, 0.29065645, 0.18934852, ..., 0.07994447, 0.52603954,
#          0.0126016 ], dtype=float32)},
#  58: {'p_id': 12,
#   'image_pth': '7a/7a46b66c.jpg',
#   'image_embedding': array([0.76471406, 0.29065645, 0.18934852, ..., 0.07994447, 0.52603954,
#          0.0126016 ], dtype=float32)},
#  59: {'p_id': 12,
#   'image_pth': '7a/7a46b66c.jpg',
#   'image_embedding': array([0.76471406, 0.29065645, 0.18934852, ..., 0.07994447, 0.52603954,
#          0.0126016 ], dtype=float32)},
#  60: {'p_id': 12,
#   'image_pth': '7a/7a46b66c.jpg',
#   'image_embedding': array([0.76471406, 0.29065645, 0.18934852, ..., 0.07994447, 0.52603954,
#          0.0126016 ], dtype=float32)},
#  61: {'p_id': 12,
#   'image_pth': '7a/7a46b66c.jpg',
#   'image_embedding': array([0.76471406, 0.29065645, 0.18934852, ..., 0.07994447, 0.52603954,
#          0.0126016 ], dtype=float32)},
#  62: {'p_id': 13,
#   'image_pth': '29/2957b26e.jpg',
#   'image_embedding': array([0.33965224, 0.2770254 , 0.03531523, ..., 0.09673709, 0.91870415,
#          0.05887032], dtype=float32)},
#  63: {'p_id': 13,
#   'image_pth': '29/2957b26e.jpg',
#   'image_embedding': array([0.33965224, 0.2770254 , 0.03531523, ..., 0.09673709, 0.91870415,
#          0.05887032], dtype=float32)},
#  64: {'p_id': 13,
#   'image_pth': '29/2957b26e.jpg',
#   'image_embedding': array([0.33965224, 0.2770254 , 0.03531523, ..., 0.09673709, 0.91870415,
#          0.05887032], dtype=float32)},
#  65: {'p_id': 13,
#   'image_pth': '29/2957b26e.jpg',
#   'image_embedding': array([0.33965224, 0.2770254 , 0.03531523, ..., 0.09673709, 0.91870415,
#          0.05887032], dtype=float32)},
#  66: {'p_id': 13,
#   'image_pth': '29/2957b26e.jpg',
#   'image_embedding': array([0.33965224, 0.2770254 , 0.03531523, ..., 0.09673709, 0.91870415,
#          0.05887032], dtype=float32)},
#  67: {'p_id': 14,
#   'image_pth': '28/28019d8d.jpg',
#   'image_embedding': array([0.70360774, 0.07728694, 0.1317501 , ..., 0.2510739 , 0.5912668 ,
#          0.1364499 ], dtype=float32)},
#  68: {'p_id': 14,
#   'image_pth': '28/28019d8d.jpg',
#   'image_embedding': array([0.70360774, 0.07728694, 0.1317501 , ..., 0.2510739 , 0.5912668 ,
#          0.1364499 ], dtype=float32)},
#  69: {'p_id': 14,
#   'image_pth': '28/28019d8d.jpg',
#   'image_embedding': array([0.70360774, 0.07728694, 0.1317501 , ..., 0.2510739 , 0.5912668 ,
#          0.1364499 ], dtype=float32)},
#  70: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  71: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  72: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  73: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  74: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  75: {'p_id': 15,
#   'image_pth': '55/55ed3324.jpg',
#   'image_embedding': array([0.44335467, 0.17612697, 0.37513083, ..., 0.26164395, 0.6632861 ,
#          0.2519872 ], dtype=float32)},
#  76: {'p_id': 16,
#   'image_pth': 'fd/fd693608.jpg',
#   'image_embedding': array([0.45192757, 1.245573  , 0.2919899 , ..., 0.29024857, 0.52028704,
#          0.12226976], dtype=float32)},
#  77: {'p_id': 16,
#   'image_pth': 'fd/fd693608.jpg',
#   'image_embedding': array([0.45192757, 1.245573  , 0.2919899 , ..., 0.29024857, 0.52028704,
#          0.12226976], dtype=float32)},
#  78: {'p_id': 16,
#   'image_pth': 'fd/fd693608.jpg',
#   'image_embedding': array([0.45192757, 1.245573  , 0.2919899 , ..., 0.29024857, 0.52028704,
#          0.12226976], dtype=float32)},
#  79: {'p_id': 16,
#   'image_pth': 'fd/fd693608.jpg',
#   'image_embedding': array([0.45192757, 1.245573  , 0.2919899 , ..., 0.29024857, 0.52028704,
#          0.12226976], dtype=float32)},
#  80: {'p_id': 16,
#   'image_pth': 'fd/fd693608.jpg',
#   'image_embedding': array([0.45192757, 1.245573  , 0.2919899 , ..., 0.29024857, 0.52028704,
#          0.12226976], dtype=float32)},
#  81: {'p_id': 17,
#   'image_pth': '64/64aa56cb.jpg',
#   'image_embedding': array([0.68261635, 0.28406036, 0.01614081, ..., 0.29738238, 0.03255739,
#          0.15888566], dtype=float32)},
#  82: {'p_id': 18,
#   'image_pth': '3f/3f6eb844.jpg',
#   'image_embedding': array([0.65485275, 0.29118893, 0.07356127, ..., 0.05385219, 0.3730076 ,
#          0.16846575], dtype=float32)},
#  83: {'p_id': 18,
#   'image_pth': '3f/3f6eb844.jpg',
#   'image_embedding': array([0.65485275, 0.29118893, 0.07356127, ..., 0.05385219, 0.3730076 ,
#          0.16846575], dtype=float32)},
#  84: {'p_id': 18,
#   'image_pth': '3f/3f6eb844.jpg',
#   'image_embedding': array([0.65485275, 0.29118893, 0.07356127, ..., 0.05385219, 0.3730076 ,
#          0.16846575], dtype=float32)},
#  85: {'p_id': 18,
#   'image_pth': '3f/3f6eb844.jpg',
#   'image_embedding': array([0.65485275, 0.29118893, 0.07356127, ..., 0.05385219, 0.3730076 ,
#          0.16846575], dtype=float32)},
#  86: {'p_id': 18,
#   'image_pth': '3f/3f6eb844.jpg',
#   'image_embedding': array([0.65485275, 0.29118893, 0.07356127, ..., 0.05385219, 0.3730076 ,
#          0.16846575], dtype=float32)},
#  87: {'p_id': 19,
#   'image_pth': 'ea/ea5469c6.jpg',
#   'image_embedding': array([0.71903837, 0.04972949, 0.0185273 , ..., 0.04417716, 0.49920645,
#          0.19159251], dtype=float32)},
#  88: {'p_id': 19,
#   'image_pth': 'ea/ea5469c6.jpg',
#   'image_embedding': array([0.71903837, 0.04972949, 0.0185273 , ..., 0.04417716, 0.49920645,
#          0.19159251], dtype=float32)},
#  89: {'p_id': 19,
#   'image_pth': 'ea/ea5469c6.jpg',
#   'image_embedding': array([0.71903837, 0.04972949, 0.0185273 , ..., 0.04417716, 0.49920645,
#          0.19159251], dtype=float32)},
#  90: {'p_id': 19,
#   'image_pth': 'ea/ea5469c6.jpg',
#   'image_embedding': array([0.71903837, 0.04972949, 0.0185273 , ..., 0.04417716, 0.49920645,
#          0.19159251], dtype=float32)},
#  91: {'p_id': 19,
#   'image_pth': 'ea/ea5469c6.jpg',
#   'image_embedding': array([0.71903837, 0.04972949, 0.0185273 , ..., 0.04417716, 0.49920645,
#          0.19159251], dtype=float32)},
#  92: {'p_id': 20,
#   'image_pth': '7d/7dc996dd.jpg',
#   'image_embedding': array([1.3347528 , 1.0029044 , 0.03539525, ..., 0.01629137, 1.1842479 ,
#          0.18307452], dtype=float32)},
#  93: {'p_id': 20,
#   'image_pth': '7d/7dc996dd.jpg',
#   'image_embedding': array([1.3347528 , 1.0029044 , 0.03539525, ..., 0.01629137, 1.1842479 ,
#          0.18307452], dtype=float32)},
#  94: {'p_id': 20,
#   'image_pth': '7d/7dc996dd.jpg',
#   'image_embedding': array([1.3347528 , 1.0029044 , 0.03539525, ..., 0.01629137, 1.1842479 ,
#          0.18307452], dtype=float32)},
#  95: {'p_id': 20,
#   'image_pth': '7d/7dc996dd.jpg',
#   'image_embedding': array([1.3347528 , 1.0029044 , 0.03539525, ..., 0.01629137, 1.1842479 ,
#          0.18307452], dtype=float32)},
#  96: {'p_id': 20,
#   'image_pth': '7d/7dc996dd.jpg',
#   'image_embedding': array([1.3347528 , 1.0029044 , 0.03539525, ..., 0.01629137, 1.1842479 ,
#          0.18307452], dtype=float32)},
#  97: {'p_id': 21,
#   'image_pth': '42/4213f453.jpg',
#   'image_embedding': array([0.44768196, 0.04044318, 1.1251543 , ..., 0.        , 0.38161162,
#          0.22518171], dtype=float32)},
#  98: {'p_id': 21,
#   'image_pth': '42/4213f453.jpg',
#   'image_embedding': array([0.44768196, 0.04044318, 1.1251543 , ..., 0.        , 0.38161162,
#          0.22518171], dtype=float32)},
#  99: {'p_id': 21,
#   'image_pth': '42/4213f453.jpg',
#   'image_embedding': array([0.44768196, 0.04044318, 1.1251543 , ..., 0.        , 0.38161162,
#          0.22518171], dtype=float32)},
#  100: {'p_id': 21,
#   'image_pth': '42/4213f453.jpg',
#   'image_embedding': array([0.44768196, 0.04044318, 1.1251543 , ..., 0.        , 0.38161162,
#          0.22518171], dtype=float32)},
#  101: {'p_id': 21,
#   'image_pth': '42/4213f453.jpg',
#   'image_embedding': array([0.44768196, 0.04044318, 1.1251543 , ..., 0.        , 0.38161162,
#          0.22518171], dtype=float32)},
#  102: {'p_id': 22,
#   'image_pth': 'ae/ae586045.jpg',
#   'image_embedding': array([0.58910453, 0.5514083 , 0.67102134, ..., 0.27237585, 0.14621781,
#          0.01501319], dtype=float32)},
#  103: {'p_id': 22,
#   'image_pth': 'ae/ae586045.jpg',
#   'image_embedding': array([0.58910453, 0.5514083 , 0.67102134, ..., 0.27237585, 0.14621781,
#          0.01501319], dtype=float32)},
#  104: {'p_id': 22,
#   'image_pth': 'ae/ae586045.jpg',
#   'image_embedding': array([0.58910453, 0.5514083 , 0.67102134, ..., 0.27237585, 0.14621781,
#          0.01501319], dtype=float32)},
#  105: {'p_id': 22,
#   'image_pth': 'ae/ae586045.jpg',
#   'image_embedding': array([0.58910453, 0.5514083 , 0.67102134, ..., 0.27237585, 0.14621781,
#          0.01501319], dtype=float32)},
#  106: {'p_id': 23,
#   'image_pth': 'eb/eb4a1f55.jpg',
#   'image_embedding': array([0.423767  , 0.06425895, 0.09933399, ..., 0.14175235, 1.2140044 ,
#          0.27915144], dtype=float32)},
#  107: {'p_id': 23,
#   'image_pth': 'eb/eb4a1f55.jpg',
#   'image_embedding': array([0.423767  , 0.06425895, 0.09933399, ..., 0.14175235, 1.2140044 ,
#          0.27915144], dtype=float32)},
#  108: {'p_id': 23,
#   'image_pth': 'eb/eb4a1f55.jpg',
#   'image_embedding': array([0.423767  , 0.06425895, 0.09933399, ..., 0.14175235, 1.2140044 ,
#          0.27915144], dtype=float32)},
#  109: {'p_id': 23,
#   'image_pth': 'eb/eb4a1f55.jpg',
#   'image_embedding': array([0.423767  , 0.06425895, 0.09933399, ..., 0.14175235, 1.2140044 ,
#          0.27915144], dtype=float32)},
#  110: {'p_id': 23,
#   'image_pth': 'eb/eb4a1f55.jpg',
#   'image_embedding': array([0.423767  , 0.06425895, 0.09933399, ..., 0.14175235, 1.2140044 ,
#          0.27915144], dtype=float32)},
#  111: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  112: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  113: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  114: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  115: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  116: {'p_id': 24,
#   'image_pth': '24/2470351d.jpg',
#   'image_embedding': array([0.87867934, 0.3469695 , 0.02878997, ..., 0.02631152, 1.0222324 ,
#          0.5805526 ], dtype=float32)},
#  117: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  118: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  119: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  120: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  121: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  122: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  123: {'p_id': 25,
#   'image_pth': 'cd/cd870277.jpg',
#   'image_embedding': array([1.3577211 , 0.44834328, 1.1800632 , ..., 0.2561995 , 4.6661234 ,
#          0.9101011 ], dtype=float32)},
#  124: {'p_id': 26,
#   'image_pth': '80/804ecc8d.jpg',
#   'image_embedding': array([0.2842354 , 0.4645694 , 0.10587905, ..., 0.31995377, 1.0165182 ,
#          0.05102744], dtype=float32)},
#  125: {'p_id': 26,
#   'image_pth': '80/804ecc8d.jpg',
#   'image_embedding': array([0.2842354 , 0.4645694 , 0.10587905, ..., 0.31995377, 1.0165182 ,
#          0.05102744], dtype=float32)},
#  126: {'p_id': 26,
#   'image_pth': '80/804ecc8d.jpg',
#   'image_embedding': array([0.2842354 , 0.4645694 , 0.10587905, ..., 0.31995377, 1.0165182 ,
#          0.05102744], dtype=float32)},
#  127: {'p_id': 27,
#   'image_pth': 'ea/ea0c6da6.jpg',
#   'image_embedding': array([1.6686057 , 0.49942905, 0.5141017 , ..., 0.35448205, 0.5585428 ,
#          0.40164372], dtype=float32)},
#  128: {'p_id': 27,
#   'image_pth': 'ea/ea0c6da6.jpg',
#   'image_embedding': array([1.6686057 , 0.49942905, 0.5141017 , ..., 0.35448205, 0.5585428 ,
#          0.40164372], dtype=float32)},
#  129: {'p_id': 27,
#   'image_pth': 'ea/ea0c6da6.jpg',
#   'image_embedding': array([1.6686057 , 0.49942905, 0.5141017 , ..., 0.35448205, 0.5585428 ,
#          0.40164372], dtype=float32)},
#  130: {'p_id': 27,
#   'image_pth': 'ea/ea0c6da6.jpg',
#   'image_embedding': array([1.6686057 , 0.49942905, 0.5141017 , ..., 0.35448205, 0.5585428 ,
#          0.40164372], dtype=float32)},
#  131: {'p_id': 28,
#   'image_pth': '4d/4d59969e.jpg',
#   'image_embedding': array([0.4578082 , 0.9611607 , 0.11568455, ..., 0.3937185 , 0.03249547,
#          0.04561887], dtype=float32)},
#  132: {'p_id': 28,
#   'image_pth': '4d/4d59969e.jpg',
#   'image_embedding': array([0.4578082 , 0.9611607 , 0.11568455, ..., 0.3937185 , 0.03249547,
#          0.04561887], dtype=float32)},
#  133: {'p_id': 28,
#   'image_pth': '4d/4d59969e.jpg',
#   'image_embedding': array([0.4578082 , 0.9611607 , 0.11568455, ..., 0.3937185 , 0.03249547,
#          0.04561887], dtype=float32)},
#  134: {'p_id': 28,
#   'image_pth': '4d/4d59969e.jpg',
#   'image_embedding': array([0.4578082 , 0.9611607 , 0.11568455, ..., 0.3937185 , 0.03249547,
#          0.04561887], dtype=float32)},
#  135: {'p_id': 29,
#   'image_pth': '04/040353c9.jpg',
#   'image_embedding': array([1.2684718 , 1.3570464 , 0.16928181, ..., 0.01047967, 1.5615504 ,
#          0.08636659], dtype=float32)},
#  136: {'p_id': 29,
#   'image_pth': '04/040353c9.jpg',
#   'image_embedding': array([1.2684718 , 1.3570464 , 0.16928181, ..., 0.01047967, 1.5615504 ,
#          0.08636659], dtype=float32)},
#  137: {'p_id': 29,
#   'image_pth': '04/040353c9.jpg',
#   'image_embedding': array([1.2684718 , 1.3570464 , 0.16928181, ..., 0.01047967, 1.5615504 ,
#          0.08636659], dtype=float32)},
#  138: {'p_id': 29,
#   'image_pth': '04/040353c9.jpg',
#   'image_embedding': array([1.2684718 , 1.3570464 , 0.16928181, ..., 0.01047967, 1.5615504 ,
#          0.08636659], dtype=float32)},
#  139: {'p_id': 29,
#   'image_pth': '04/040353c9.jpg',
#   'image_embedding': array([1.2684718 , 1.3570464 , 0.16928181, ..., 0.01047967, 1.5615504 ,
#          0.08636659], dtype=float32)},
#  140: {'p_id': 30,
#   'image_pth': '35/3595924e.jpg',
#   'image_embedding': array([0.2278249 , 0.696579  , 0.03359977, ..., 0.05383448, 0.00748633,
#          0.0276894 ], dtype=float32)},
#  141: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  142: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  143: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  144: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  145: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  146: {'p_id': 31,
#   'image_pth': 'd1/d1f6a50a.jpg',
#   'image_embedding': array([1.110571  , 0.07510138, 0.42597607, ..., 0.21891396, 0.27933896,
#          0.05258112], dtype=float32)},
#  147: {'p_id': 32,
#   'image_pth': '81/81170d88.jpg',
#   'image_embedding': array([0.36176977, 1.4351951 , 0.00785325, ..., 0.00804561, 0.44810882,
#          0.13812745], dtype=float32)},
#  148: {'p_id': 32,
#   'image_pth': '81/81170d88.jpg',
#   'image_embedding': array([0.36176977, 1.4351951 , 0.00785325, ..., 0.00804561, 0.44810882,
#          0.13812745], dtype=float32)},
#  149: {'p_id': 32,
#   'image_pth': '81/81170d88.jpg',
#   'image_embedding': array([0.36176977, 1.4351951 , 0.00785325, ..., 0.00804561, 0.44810882,
#          0.13812745], dtype=float32)},
#  150: {'p_id': 32,
#   'image_pth': '81/81170d88.jpg',
#   'image_embedding': array([0.36176977, 1.4351951 , 0.00785325, ..., 0.00804561, 0.44810882,
#          0.13812745], dtype=float32)},
#  151: {'p_id': 32,
#   'image_pth': '81/81170d88.jpg',
#   'image_embedding': array([0.36176977, 1.4351951 , 0.00785325, ..., 0.00804561, 0.44810882,
#          0.13812745], dtype=float32)},
#  152: {'p_id': 33,
#   'image_pth': 'a1/a1aaf4c0.jpg',
#   'image_embedding': array([0.70456016, 0.22481593, 0.11402158, ..., 0.03791878, 0.5619668 ,
#          0.24658386], dtype=float32)},
#  153: {'p_id': 33,
#   'image_pth': 'a1/a1aaf4c0.jpg',
#   'image_embedding': array([0.70456016, 0.22481593, 0.11402158, ..., 0.03791878, 0.5619668 ,
#          0.24658386], dtype=float32)},
#  154: {'p_id': 33,
#   'image_pth': 'a1/a1aaf4c0.jpg',
#   'image_embedding': array([0.70456016, 0.22481593, 0.11402158, ..., 0.03791878, 0.5619668 ,
#          0.24658386], dtype=float32)},
#  155: {'p_id': 33,
#   'image_pth': 'a1/a1aaf4c0.jpg',
#   'image_embedding': array([0.70456016, 0.22481593, 0.11402158, ..., 0.03791878, 0.5619668 ,
#          0.24658386], dtype=float32)},
#  156: {'p_id': 33,
#   'image_pth': 'a1/a1aaf4c0.jpg',
#   'image_embedding': array([0.70456016, 0.22481593, 0.11402158, ..., 0.03791878, 0.5619668 ,
#          0.24658386], dtype=float32)},
#  157: {'p_id': 34,
#   'image_pth': 'cb/cb728deb.jpg',
#   'image_embedding': array([0.7267294 , 0.47419018, 0.4491984 , ..., 0.23179288, 2.7629497 ,
#          0.47362125], dtype=float32)},
#  158: {'p_id': 34,
#   'image_pth': 'cb/cb728deb.jpg',
#   'image_embedding': array([0.7267294 , 0.47419018, 0.4491984 , ..., 0.23179288, 2.7629497 ,
#          0.47362125], dtype=float32)},
#  159: {'p_id': 34,
#   'image_pth': 'cb/cb728deb.jpg',
#   'image_embedding': array([0.7267294 , 0.47419018, 0.4491984 , ..., 0.23179288, 2.7629497 ,
#          0.47362125], dtype=float32)},
#  160: {'p_id': 34,
#   'image_pth': 'cb/cb728deb.jpg',
#   'image_embedding': array([0.7267294 , 0.47419018, 0.4491984 , ..., 0.23179288, 2.7629497 ,
#          0.47362125], dtype=float32)},
#  161: {'p_id': 34,
#   'image_pth': 'cb/cb728deb.jpg',
#   'image_embedding': array([0.7267294 , 0.47419018, 0.4491984 , ..., 0.23179288, 2.7629497 ,
#          0.47362125], dtype=float32)},
#  162: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  163: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  164: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  165: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  166: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  167: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  168: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  169: {'p_id': 35,
#   'image_pth': '14/14d129a0.jpg',
#   'image_embedding': array([0.93289965, 0.4363351 , 0.59085065, ..., 0.30704293, 3.54946   ,
#          1.6073004 ], dtype=float32)},
#  170: {'p_id': 36,
#   'image_pth': '00/0055d71a.jpg',
#   'image_embedding': array([1.1188442 , 0.2054624 , 0.1517421 , ..., 0.00720563, 0.1720253 ,
#          0.21382217], dtype=float32)},
#  171: {'p_id': 36,
#   'image_pth': '00/0055d71a.jpg',
#   'image_embedding': array([1.1188442 , 0.2054624 , 0.1517421 , ..., 0.00720563, 0.1720253 ,
#          0.21382217], dtype=float32)},
#  172: {'p_id': 36,
#   'image_pth': '00/0055d71a.jpg',
#   'image_embedding': array([1.1188442 , 0.2054624 , 0.1517421 , ..., 0.00720563, 0.1720253 ,
#          0.21382217], dtype=float32)},
#  173: {'p_id': 36,
#   'image_pth': '00/0055d71a.jpg',
#   'image_embedding': array([1.1188442 , 0.2054624 , 0.1517421 , ..., 0.00720563, 0.1720253 ,
#          0.21382217], dtype=float32)},
#  174: {'p_id': 36,
#   'image_pth': '00/0055d71a.jpg',
#   'image_embedding': array([1.1188442 , 0.2054624 , 0.1517421 , ..., 0.00720563, 0.1720253 ,
#          0.21382217], dtype=float32)},
#  175: {'p_id': 37,
#   'image_pth': '45/454c2616.jpg',
#   'image_embedding': array([0.6294702 , 0.36921248, 0.03651614, ..., 0.24197584, 0.14180219,
#          0.27081183], dtype=float32)},
#  176: {'p_id': 37,
#   'image_pth': '45/454c2616.jpg',
#   'image_embedding': array([0.6294702 , 0.36921248, 0.03651614, ..., 0.24197584, 0.14180219,
#          0.27081183], dtype=float32)},
#  177: {'p_id': 37,
#   'image_pth': '45/454c2616.jpg',
#   'image_embedding': array([0.6294702 , 0.36921248, 0.03651614, ..., 0.24197584, 0.14180219,
#          0.27081183], dtype=float32)},
#  178: {'p_id': 37,
#   'image_pth': '45/454c2616.jpg',
#   'image_embedding': array([0.6294702 , 0.36921248, 0.03651614, ..., 0.24197584, 0.14180219,
#          0.27081183], dtype=float32)},
#  179: {'p_id': 37,
#   'image_pth': '45/454c2616.jpg',
#   'image_embedding': array([0.6294702 , 0.36921248, 0.03651614, ..., 0.24197584, 0.14180219,
#          0.27081183], dtype=float32)},
#  180: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  181: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  182: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  183: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  184: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  185: {'p_id': 38,
#   'image_pth': 'f4/f4f31eec.jpg',
#   'image_embedding': array([0.44675767, 0.32994017, 1.0306009 , ..., 0.38331866, 3.3212929 ,
#          1.6524211 ], dtype=float32)},
#  186: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  187: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  188: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  189: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  190: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  191: {'p_id': 39,
#   'image_pth': 'e7/e7983ec5.jpg',
#   'image_embedding': array([0.5200646 , 0.12925023, 0.6544813 , ..., 0.40148282, 0.44094387,
#          0.44534108], dtype=float32)},
#  192: {'p_id': 40,
#   'image_pth': '64/641ff5a1.jpg',
#   'image_embedding': array([0.5417454 , 0.67061824, 0.06195736, ..., 0.0102131 , 0.20336722,
#          0.65418756], dtype=float32)},
#  193: {'p_id': 40,
#   'image_pth': '64/641ff5a1.jpg',
#   'image_embedding': array([0.5417454 , 0.67061824, 0.06195736, ..., 0.0102131 , 0.20336722,
#          0.65418756], dtype=float32)},
#  194: {'p_id': 40,
#   'image_pth': '64/641ff5a1.jpg',
#   'image_embedding': array([0.5417454 , 0.67061824, 0.06195736, ..., 0.0102131 , 0.20336722,
#          0.65418756], dtype=float32)},
#  195: {'p_id': 40,
#   'image_pth': '64/641ff5a1.jpg',
#   'image_embedding': array([0.5417454 , 0.67061824, 0.06195736, ..., 0.0102131 , 0.20336722,
#          0.65418756], dtype=float32)},
#  196: {'p_id': 40,
#   'image_pth': '64/641ff5a1.jpg',
#   'image_embedding': array([0.5417454 , 0.67061824, 0.06195736, ..., 0.0102131 , 0.20336722,
#          0.65418756], dtype=float32)},
#  197: {'p_id': 41,
#   'image_pth': 'e0/e038f87a.jpg',
#   'image_embedding': array([0.256696  , 0.86324453, 0.45467207, ..., 0.1272945 , 0.04378451,
#          0.43109363], dtype=float32)},
#  198: {'p_id': 41,
#   'image_pth': 'e0/e038f87a.jpg',
#   'image_embedding': array([0.256696  , 0.86324453, 0.45467207, ..., 0.1272945 , 0.04378451,
#          0.43109363], dtype=float32)},
#  199: {'p_id': 41,
#   'image_pth': 'e0/e038f87a.jpg',
#   'image_embedding': array([0.256696  , 0.86324453, 0.45467207, ..., 0.1272945 , 0.04378451,
#          0.43109363], dtype=float32)},
#  200: {'p_id': 41,
#   'image_pth': 'e0/e038f87a.jpg',
#   'image_embedding': array([0.256696  , 0.86324453, 0.45467207, ..., 0.1272945 , 0.04378451,
#          0.43109363], dtype=float32)},
#  201: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  202: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  203: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  204: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  205: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  206: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  207: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  208: {'p_id': 42,
#   'image_pth': '05/051b1105.jpg',
#   'image_embedding': array([0.15929414, 0.120484  , 0.8341117 , ..., 0.7711616 , 1.7721049 ,
#          0.8990328 ], dtype=float32)},
#  209: {'p_id': 43,
#   'image_pth': '65/65310b27.jpg',
#   'image_embedding': array([0.7045126 , 0.13770886, 0.22257437, ..., 0.3057399 , 1.005946  ,
#          0.1758335 ], dtype=float32)},
#  210: {'p_id': 43,
#   'image_pth': '65/65310b27.jpg',
#   'image_embedding': array([0.7045126 , 0.13770886, 0.22257437, ..., 0.3057399 , 1.005946  ,
#          0.1758335 ], dtype=float32)},
#  211: {'p_id': 43,
#   'image_pth': '65/65310b27.jpg',
#   'image_embedding': array([0.7045126 , 0.13770886, 0.22257437, ..., 0.3057399 , 1.005946  ,
#          0.1758335 ], dtype=float32)},
#  212: {'p_id': 43,
#   'image_pth': '65/65310b27.jpg',
#   'image_embedding': array([0.7045126 , 0.13770886, 0.22257437, ..., 0.3057399 , 1.005946  ,
#          0.1758335 ], dtype=float32)},
#  213: {'p_id': 43,
#   'image_pth': '65/65310b27.jpg',
#   'image_embedding': array([0.7045126 , 0.13770886, 0.22257437, ..., 0.3057399 , 1.005946  ,
#          0.1758335 ], dtype=float32)},
#  214: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  215: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  216: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  217: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  218: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  219: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  220: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  221: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  222: {'p_id': 44,
#   'image_pth': 'dc/dcf40fb6.jpg',
#   'image_embedding': array([0.27441284, 1.2577118 , 0.06093339, ..., 0.44823274, 0.12220351,
#          0.26574636], dtype=float32)},
#  223: {'p_id': 45,
#   'image_pth': '0d/0d4cd1f0.jpg',
#   'image_embedding': array([0.31593794, 0.20101857, 0.51741034, ..., 0.00395172, 0.04434184,
#          0.07928953], dtype=float32)},
#  224: {'p_id': 45,
#   'image_pth': '0d/0d4cd1f0.jpg',
#   'image_embedding': array([0.31593794, 0.20101857, 0.51741034, ..., 0.00395172, 0.04434184,
#          0.07928953], dtype=float32)},
#  225: {'p_id': 45,
#   'image_pth': '0d/0d4cd1f0.jpg',
#   'image_embedding': array([0.31593794, 0.20101857, 0.51741034, ..., 0.00395172, 0.04434184,
#          0.07928953], dtype=float32)},
#  226: {'p_id': 45,
#   'image_pth': '0d/0d4cd1f0.jpg',
#   'image_embedding': array([0.31593794, 0.20101857, 0.51741034, ..., 0.00395172, 0.04434184,
#          0.07928953], dtype=float32)},
#  227: {'p_id': 46,
#   'image_pth': '65/65811a98.jpg',
#   'image_embedding': array([0.7494207 , 0.5483266 , 0.01475059, ..., 0.12327649, 0.7942709 ,
#          0.1851939 ], dtype=float32)},
#  228: {'p_id': 46,
#   'image_pth': '65/65811a98.jpg',
#   'image_embedding': array([0.7494207 , 0.5483266 , 0.01475059, ..., 0.12327649, 0.7942709 ,
#          0.1851939 ], dtype=float32)},
#  229: {'p_id': 46,
#   'image_pth': '65/65811a98.jpg',
#   'image_embedding': array([0.7494207 , 0.5483266 , 0.01475059, ..., 0.12327649, 0.7942709 ,
#          0.1851939 ], dtype=float32)},
#  230: {'p_id': 46,
#   'image_pth': '65/65811a98.jpg',
#   'image_embedding': array([0.7494207 , 0.5483266 , 0.01475059, ..., 0.12327649, 0.7942709 ,
#          0.1851939 ], dtype=float32)},
#  231: {'p_id': 46,
#   'image_pth': '65/65811a98.jpg',
#   'image_embedding': array([0.7494207 , 0.5483266 , 0.01475059, ..., 0.12327649, 0.7942709 ,
#          0.1851939 ], dtype=float32)},
#  232: {'p_id': 47,
#   'image_pth': 'f7/f773eeb4.jpg',
#   'image_embedding': array([0.68968564, 0.01486223, 0.5079814 , ..., 0.00533118, 1.2941    ,
#          0.29078108], dtype=float32)},
#  233: {'p_id': 47,
#   'image_pth': 'f7/f773eeb4.jpg',
#   'image_embedding': array([0.68968564, 0.01486223, 0.5079814 , ..., 0.00533118, 1.2941    ,
#          0.29078108], dtype=float32)},
#  234: {'p_id': 47,
#   'image_pth': 'f7/f773eeb4.jpg',
#   'image_embedding': array([0.68968564, 0.01486223, 0.5079814 , ..., 0.00533118, 1.2941    ,
#          0.29078108], dtype=float32)},
#  235: {'p_id': 48,
#   'image_pth': 'b6/b630bf31.jpg',
#   'image_embedding': array([0.9930381 , 0.7573044 , 0.64836377, ..., 0.3663989 , 2.9032505 ,
#          0.34360147], dtype=float32)},
#  236: {'p_id': 48,
#   'image_pth': 'b6/b630bf31.jpg',
#   'image_embedding': array([0.9930381 , 0.7573044 , 0.64836377, ..., 0.3663989 , 2.9032505 ,
#          0.34360147], dtype=float32)},
#  237: {'p_id': 48,
#   'image_pth': 'b6/b630bf31.jpg',
#   'image_embedding': array([0.9930381 , 0.7573044 , 0.64836377, ..., 0.3663989 , 2.9032505 ,
#          0.34360147], dtype=float32)},
#  238: {'p_id': 48,
#   'image_pth': 'b6/b630bf31.jpg',
#   'image_embedding': array([0.9930381 , 0.7573044 , 0.64836377, ..., 0.3663989 , 2.9032505 ,
#          0.34360147], dtype=float32)},
#  239: {'p_id': 49,
#   'image_pth': 'cd/cd2f33b3.jpg',
#   'image_embedding': array([1.1973149 , 0.07425674, 1.195179  , ..., 0.49958658, 1.1212796 ,
#          0.93874276], dtype=float32)},
#  240: {'p_id': 49,
#   'image_pth': 'cd/cd2f33b3.jpg',
#   'image_embedding': array([1.1973149 , 0.07425674, 1.195179  , ..., 0.49958658, 1.1212796 ,
#          0.93874276], dtype=float32)},
#  241: {'p_id': 49,
#   'image_pth': 'cd/cd2f33b3.jpg',
#   'image_embedding': array([1.1973149 , 0.07425674, 1.195179  , ..., 0.49958658, 1.1212796 ,
#          0.93874276], dtype=float32)},
#  242: {'p_id': 50,
#   'image_pth': 'fb/fb168e1f.jpg',
#   'image_embedding': array([0.74082845, 0.1508391 , 0.0935403 , ..., 0.1640613 , 0.48552448,
#          0.13072324], dtype=float32)},
#  243: {'p_id': 51,
#   'image_pth': 'db/db7169d3.jpg',
#   'image_embedding': array([0.72278184, 0.58325636, 0.22405654, ..., 0.09746251, 0.64641297,
#          0.61848736], dtype=float32)},
#  244: {'p_id': 51,
#   'image_pth': 'db/db7169d3.jpg',
#   'image_embedding': array([0.72278184, 0.58325636, 0.22405654, ..., 0.09746251, 0.64641297,
#          0.61848736], dtype=float32)},
#  245: {'p_id': 52,
#   'image_pth': '34/342b203d.jpg',
#   'image_embedding': array([0.69644314, 0.4641034 , 0.21564446, ..., 0.03509155, 0.62436086,
#          0.30236506], dtype=float32)},
#  246: {'p_id': 52,
#   'image_pth': '34/342b203d.jpg',
#   'image_embedding': array([0.69644314, 0.4641034 , 0.21564446, ..., 0.03509155, 0.62436086,
#          0.30236506], dtype=float32)},
#  247: {'p_id': 52,
#   'image_pth': '34/342b203d.jpg',
#   'image_embedding': array([0.69644314, 0.4641034 , 0.21564446, ..., 0.03509155, 0.62436086,
#          0.30236506], dtype=float32)},
#  248: {'p_id': 52,
#   'image_pth': '34/342b203d.jpg',
#   'image_embedding': array([0.69644314, 0.4641034 , 0.21564446, ..., 0.03509155, 0.62436086,
#          0.30236506], dtype=float32)},
#  249: {'p_id': 52,
#   'image_pth': '34/342b203d.jpg',
#   'image_embedding': array([0.69644314, 0.4641034 , 0.21564446, ..., 0.03509155, 0.62436086,
#          0.30236506], dtype=float32)},
#  250: {'p_id': 53,
#   'image_pth': '38/380e103c.jpg',
#   'image_embedding': array([0.9517313 , 0.35222825, 1.3459835 , ..., 0.04391744, 0.9040057 ,
#          0.19954821], dtype=float32)},
#  251: {'p_id': 53,
#   'image_pth': '38/380e103c.jpg',
#   'image_embedding': array([0.9517313 , 0.35222825, 1.3459835 , ..., 0.04391744, 0.9040057 ,
#          0.19954821], dtype=float32)},
#  252: {'p_id': 53,
#   'image_pth': '38/380e103c.jpg',
#   'image_embedding': array([0.9517313 , 0.35222825, 1.3459835 , ..., 0.04391744, 0.9040057 ,
#          0.19954821], dtype=float32)},
#  253: {'p_id': 53,
#   'image_pth': '38/380e103c.jpg',
#   'image_embedding': array([0.9517313 , 0.35222825, 1.3459835 , ..., 0.04391744, 0.9040057 ,
#          0.19954821], dtype=float32)},
#  254: {'p_id': 54,
#   'image_pth': 'bd/bdb778cb.jpg',
#   'image_embedding': array([0.7822598 , 0.5032501 , 0.38966852, ..., 0.22970869, 0.17152038,
#          0.1061957 ], dtype=float32)},
#  255: {'p_id': 54,
#   'image_pth': 'bd/bdb778cb.jpg',
#   'image_embedding': array([0.7822598 , 0.5032501 , 0.38966852, ..., 0.22970869, 0.17152038,
#          0.1061957 ], dtype=float32)},
#  256: {'p_id': 54,
#   'image_pth': 'bd/bdb778cb.jpg',
#   'image_embedding': array([0.7822598 , 0.5032501 , 0.38966852, ..., 0.22970869, 0.17152038,
#          0.1061957 ], dtype=float32)},
#  257: {'p_id': 54,
#   'image_pth': 'bd/bdb778cb.jpg',
#   'image_embedding': array([0.7822598 , 0.5032501 , 0.38966852, ..., 0.22970869, 0.17152038,
#          0.1061957 ], dtype=float32)},
#  258: {'p_id': 55,
#   'image_pth': '66/66cafa54.jpg',
#   'image_embedding': array([0.23409227, 0.19548167, 0.01049475, ..., 0.10247829, 0.17251867,
#          0.07955124], dtype=float32)},
#  259: {'p_id': 55,
#   'image_pth': '66/66cafa54.jpg',
#   'image_embedding': array([0.23409227, 0.19548167, 0.01049475, ..., 0.10247829, 0.17251867,
#          0.07955124], dtype=float32)},
#  260: {'p_id': 55,
#   'image_pth': '66/66cafa54.jpg',
# ...
#   'image_pth': '72/72f1acbe.jpg',
#   'image_embedding': array([1.1464438 , 0.44954783, 0.5896636 , ..., 0.41057074, 1.151148  ,
#          0.74602884], dtype=float32)},
#  915: {'p_id': 193,
#   'image_pth': '72/72f1acbe.jpg',
#   'image_embedding': array([1.1464438 , 0.44954783, 0.5896636 , ..., 0.41057074, 1.151148  ,
#          0.74602884], dtype=float32)},
#  916: {'p_id': 193,
#   'image_pth': '72/72f1acbe.jpg',
#   'image_embedding': array([1.1464438 , 0.44954783, 0.5896636 , ..., 0.41057074, 1.151148  ,
#          0.74602884], dtype=float32)},
#  917: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  918: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  919: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  920: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  921: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  922: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  923: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  924: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  925: {'p_id': 194,
#   'image_pth': '48/489a9abd.jpg',
#   'image_embedding': array([0.3586548 , 1.0781221 , 0.9251256 , ..., 0.2053152 , 0.34060544,
#          0.80474555], dtype=float32)},
#  926: {'p_id': 195,
#   'image_pth': '03/03d75675.jpg',
#   'image_embedding': array([0.7482944 , 1.568217  , 0.0511031 , ..., 0.03928129, 0.68866366,
#          0.4153493 ], dtype=float32)},
#  927: {'p_id': 195,
#   'image_pth': '03/03d75675.jpg',
#   'image_embedding': array([0.7482944 , 1.568217  , 0.0511031 , ..., 0.03928129, 0.68866366,
#          0.4153493 ], dtype=float32)},
#  928: {'p_id': 195,
#   'image_pth': '03/03d75675.jpg',
#   'image_embedding': array([0.7482944 , 1.568217  , 0.0511031 , ..., 0.03928129, 0.68866366,
#          0.4153493 ], dtype=float32)},
#  929: {'p_id': 196,
#   'image_pth': 'a8/a891a3b2.jpg',
#   'image_embedding': array([0.8620249 , 0.16589704, 0.19166063, ..., 0.08280735, 0.92619735,
#          0.16195576], dtype=float32)},
#  930: {'p_id': 196,
#   'image_pth': 'a8/a891a3b2.jpg',
#   'image_embedding': array([0.8620249 , 0.16589704, 0.19166063, ..., 0.08280735, 0.92619735,
#          0.16195576], dtype=float32)},
#  931: {'p_id': 196,
#   'image_pth': 'a8/a891a3b2.jpg',
#   'image_embedding': array([0.8620249 , 0.16589704, 0.19166063, ..., 0.08280735, 0.92619735,
#          0.16195576], dtype=float32)},
#  932: {'p_id': 196,
#   'image_pth': 'a8/a891a3b2.jpg',
#   'image_embedding': array([0.8620249 , 0.16589704, 0.19166063, ..., 0.08280735, 0.92619735,
#          0.16195576], dtype=float32)},
#  933: {'p_id': 196,
#   'image_pth': 'a8/a891a3b2.jpg',
#   'image_embedding': array([0.8620249 , 0.16589704, 0.19166063, ..., 0.08280735, 0.92619735,
#          0.16195576], dtype=float32)},
#  934: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  935: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  936: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  937: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  938: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  939: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  940: {'p_id': 197,
#   'image_pth': '8b/8b651194.jpg',
#   'image_embedding': array([1.7701155 , 0.12930846, 0.0678364 , ..., 0.09038201, 0.5394252 ,
#          0.6651911 ], dtype=float32)},
#  941: {'p_id': 198,
#   'image_pth': 'ff/ffd0bfbb.jpg',
#   'image_embedding': array([0.7980474 , 0.6168286 , 0.65330625, ..., 0.25171822, 2.8458576 ,
#          0.10334226], dtype=float32)},
#  942: {'p_id': 198,
#   'image_pth': 'ff/ffd0bfbb.jpg',
#   'image_embedding': array([0.7980474 , 0.6168286 , 0.65330625, ..., 0.25171822, 2.8458576 ,
#          0.10334226], dtype=float32)},
#  943: {'p_id': 198,
#   'image_pth': 'ff/ffd0bfbb.jpg',
#   'image_embedding': array([0.7980474 , 0.6168286 , 0.65330625, ..., 0.25171822, 2.8458576 ,
#          0.10334226], dtype=float32)},
#  944: {'p_id': 198,
#   'image_pth': 'ff/ffd0bfbb.jpg',
#   'image_embedding': array([0.7980474 , 0.6168286 , 0.65330625, ..., 0.25171822, 2.8458576 ,
#          0.10334226], dtype=float32)},
#  945: {'p_id': 199,
#   'image_pth': '04/04f69fd3.jpg',
#   'image_embedding': array([0.69045556, 1.848165  , 0.06419413, ..., 0.05069424, 0.49745128,
#          0.12776183], dtype=float32)},
#  946: {'p_id': 199,
#   'image_pth': '04/04f69fd3.jpg',
#   'image_embedding': array([0.69045556, 1.848165  , 0.06419413, ..., 0.05069424, 0.49745128,
#          0.12776183], dtype=float32)},
#  947: {'p_id': 199,
#   'image_pth': '04/04f69fd3.jpg',
#   'image_embedding': array([0.69045556, 1.848165  , 0.06419413, ..., 0.05069424, 0.49745128,
#          0.12776183], dtype=float32)},
#  948: {'p_id': 199,
#   'image_pth': '04/04f69fd3.jpg',
#   'image_embedding': array([0.69045556, 1.848165  , 0.06419413, ..., 0.05069424, 0.49745128,
#          0.12776183], dtype=float32)},
#  949: {'p_id': 199,
#   'image_pth': '04/04f69fd3.jpg',
#   'image_embedding': array([0.69045556, 1.848165  , 0.06419413, ..., 0.05069424, 0.49745128,
#          0.12776183], dtype=float32)},
#  950: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  951: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  952: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  953: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  954: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  955: {'p_id': 200,
#   'image_pth': '07/07410986.jpg',
#   'image_embedding': array([0.12887774, 0.10395272, 0.1659925 , ..., 0.23517756, 0.15280369,
#          0.02209564], dtype=float32)},
#  956: {'p_id': 201,
#   'image_pth': '89/898b33a6.jpg',
#   'image_embedding': array([0.65183276, 0.43293473, 0.08096769, ..., 0.30486485, 0.01815023,
#          0.4977461 ], dtype=float32)},
#  957: {'p_id': 202,
#   'image_pth': '7b/7b8cf878.jpg',
#   'image_embedding': array([0.9964463 , 0.07134219, 0.48052034, ..., 0.11029221, 0.8173782 ,
#          0.00790619], dtype=float32)},
#  958: {'p_id': 202,
#   'image_pth': '7b/7b8cf878.jpg',
#   'image_embedding': array([0.9964463 , 0.07134219, 0.48052034, ..., 0.11029221, 0.8173782 ,
#          0.00790619], dtype=float32)},
#  959: {'p_id': 202,
#   'image_pth': '7b/7b8cf878.jpg',
#   'image_embedding': array([0.9964463 , 0.07134219, 0.48052034, ..., 0.11029221, 0.8173782 ,
#          0.00790619], dtype=float32)},
#  960: {'p_id': 202,
#   'image_pth': '7b/7b8cf878.jpg',
#   'image_embedding': array([0.9964463 , 0.07134219, 0.48052034, ..., 0.11029221, 0.8173782 ,
#          0.00790619], dtype=float32)},
#  961: {'p_id': 202,
#   'image_pth': '7b/7b8cf878.jpg',
#   'image_embedding': array([0.9964463 , 0.07134219, 0.48052034, ..., 0.11029221, 0.8173782 ,
#          0.00790619], dtype=float32)},
#  962: {'p_id': 203,
#   'image_pth': '3a/3a289f47.jpg',
#   'image_embedding': array([1.1077923 , 0.400634  , 0.289369  , ..., 0.01632724, 0.7476667 ,
#          0.41283685], dtype=float32)},
#  963: {'p_id': 203,
#   'image_pth': '3a/3a289f47.jpg',
#   'image_embedding': array([1.1077923 , 0.400634  , 0.289369  , ..., 0.01632724, 0.7476667 ,
#          0.41283685], dtype=float32)},
#  964: {'p_id': 203,
#   'image_pth': '3a/3a289f47.jpg',
#   'image_embedding': array([1.1077923 , 0.400634  , 0.289369  , ..., 0.01632724, 0.7476667 ,
#          0.41283685], dtype=float32)},
#  965: {'p_id': 203,
#   'image_pth': '3a/3a289f47.jpg',
#   'image_embedding': array([1.1077923 , 0.400634  , 0.289369  , ..., 0.01632724, 0.7476667 ,
#          0.41283685], dtype=float32)},
#  966: {'p_id': 203,
#   'image_pth': '3a/3a289f47.jpg',
#   'image_embedding': array([1.1077923 , 0.400634  , 0.289369  , ..., 0.01632724, 0.7476667 ,
#          0.41283685], dtype=float32)},
#  967: {'p_id': 204,
#   'image_pth': '4c/4c8f85ea.jpg',
#   'image_embedding': array([0.37604213, 0.2800309 , 0.92757803, ..., 0.06169758, 2.1567745 ,
#          0.12053636], dtype=float32)},
#  968: {'p_id': 204,
#   'image_pth': '4c/4c8f85ea.jpg',
#   'image_embedding': array([0.37604213, 0.2800309 , 0.92757803, ..., 0.06169758, 2.1567745 ,
#          0.12053636], dtype=float32)},
#  969: {'p_id': 204,
#   'image_pth': '4c/4c8f85ea.jpg',
#   'image_embedding': array([0.37604213, 0.2800309 , 0.92757803, ..., 0.06169758, 2.1567745 ,
#          0.12053636], dtype=float32)},
#  970: {'p_id': 204,
#   'image_pth': '4c/4c8f85ea.jpg',
#   'image_embedding': array([0.37604213, 0.2800309 , 0.92757803, ..., 0.06169758, 2.1567745 ,
#          0.12053636], dtype=float32)},
#  971: {'p_id': 204,
#   'image_pth': '4c/4c8f85ea.jpg',
#   'image_embedding': array([0.37604213, 0.2800309 , 0.92757803, ..., 0.06169758, 2.1567745 ,
#          0.12053636], dtype=float32)},
#  972: {'p_id': 205,
#   'image_pth': '4c/4cf5050c.jpg',
#   'image_embedding': array([0.97970945, 0.12642564, 0.14072832, ..., 0.00660419, 0.73667353,
#          0.03555022], dtype=float32)},
#  973: {'p_id': 205,
#   'image_pth': '4c/4cf5050c.jpg',
#   'image_embedding': array([0.97970945, 0.12642564, 0.14072832, ..., 0.00660419, 0.73667353,
#          0.03555022], dtype=float32)},
#  974: {'p_id': 205,
#   'image_pth': '4c/4cf5050c.jpg',
#   'image_embedding': array([0.97970945, 0.12642564, 0.14072832, ..., 0.00660419, 0.73667353,
#          0.03555022], dtype=float32)},
#  975: {'p_id': 205,
#   'image_pth': '4c/4cf5050c.jpg',
#   'image_embedding': array([0.97970945, 0.12642564, 0.14072832, ..., 0.00660419, 0.73667353,
#          0.03555022], dtype=float32)},
#  976: {'p_id': 205,
#   'image_pth': '4c/4cf5050c.jpg',
#   'image_embedding': array([0.97970945, 0.12642564, 0.14072832, ..., 0.00660419, 0.73667353,
#          0.03555022], dtype=float32)},
#  977: {'p_id': 206,
#   'image_pth': 'c9/c9be98da.jpg',
#   'image_embedding': array([0.949695  , 0.85321987, 0.22580978, ..., 0.15209965, 0.60162306,
#          0.06207625], dtype=float32)},
#  978: {'p_id': 206,
#   'image_pth': 'c9/c9be98da.jpg',
#   'image_embedding': array([0.949695  , 0.85321987, 0.22580978, ..., 0.15209965, 0.60162306,
#          0.06207625], dtype=float32)},
#  979: {'p_id': 206,
#   'image_pth': 'c9/c9be98da.jpg',
#   'image_embedding': array([0.949695  , 0.85321987, 0.22580978, ..., 0.15209965, 0.60162306,
#          0.06207625], dtype=float32)},
#  980: {'p_id': 206,
#   'image_pth': 'c9/c9be98da.jpg',
#   'image_embedding': array([0.949695  , 0.85321987, 0.22580978, ..., 0.15209965, 0.60162306,
#          0.06207625], dtype=float32)},
#  981: {'p_id': 206,
#   'image_pth': 'c9/c9be98da.jpg',
#   'image_embedding': array([0.949695  , 0.85321987, 0.22580978, ..., 0.15209965, 0.60162306,
#          0.06207625], dtype=float32)},
#  982: {'p_id': 207,
#   'image_pth': '75/75943539.jpg',
#   'image_embedding': array([0.47216302, 0.16452706, 0.38073793, ..., 0.01152045, 0.3446039 ,
#          0.00159571], dtype=float32)},
#  983: {'p_id': 207,
#   'image_pth': '75/75943539.jpg',
#   'image_embedding': array([0.47216302, 0.16452706, 0.38073793, ..., 0.01152045, 0.3446039 ,
#          0.00159571], dtype=float32)},
#  984: {'p_id': 207,
#   'image_pth': '75/75943539.jpg',
#   'image_embedding': array([0.47216302, 0.16452706, 0.38073793, ..., 0.01152045, 0.3446039 ,
#          0.00159571], dtype=float32)},
#  985: {'p_id': 207,
#   'image_pth': '75/75943539.jpg',
#   'image_embedding': array([0.47216302, 0.16452706, 0.38073793, ..., 0.01152045, 0.3446039 ,
#          0.00159571], dtype=float32)},
#  986: {'p_id': 207,
#   'image_pth': '75/75943539.jpg',
#   'image_embedding': array([0.47216302, 0.16452706, 0.38073793, ..., 0.01152045, 0.3446039 ,
#          0.00159571], dtype=float32)},
#  987: {'p_id': 208,
#   'image_pth': 'd0/d095db48.jpg',
#   'image_embedding': array([0.5482043 , 0.27731854, 0.13473137, ..., 0.14756133, 0.51619554,
#          0.04058166], dtype=float32)},
#  988: {'p_id': 208,
#   'image_pth': 'd0/d095db48.jpg',
#   'image_embedding': array([0.5482043 , 0.27731854, 0.13473137, ..., 0.14756133, 0.51619554,
#          0.04058166], dtype=float32)},
#  989: {'p_id': 208,
#   'image_pth': 'd0/d095db48.jpg',
#   'image_embedding': array([0.5482043 , 0.27731854, 0.13473137, ..., 0.14756133, 0.51619554,
#          0.04058166], dtype=float32)},
#  990: {'p_id': 209,
#   'image_pth': '4a/4a664397.jpg',
#   'image_embedding': array([0.34897223, 0.45219484, 0.5163168 , ..., 0.42961743, 1.6848629 ,
#          0.25942007], dtype=float32)},
#  991: {'p_id': 209,
#   'image_pth': '4a/4a664397.jpg',
#   'image_embedding': array([0.34897223, 0.45219484, 0.5163168 , ..., 0.42961743, 1.6848629 ,
#          0.25942007], dtype=float32)},
#  992: {'p_id': 209,
#   'image_pth': '4a/4a664397.jpg',
#   'image_embedding': array([0.34897223, 0.45219484, 0.5163168 , ..., 0.42961743, 1.6848629 ,
#          0.25942007], dtype=float32)},
#  993: {'p_id': 209,
#   'image_pth': '4a/4a664397.jpg',
#   'image_embedding': array([0.34897223, 0.45219484, 0.5163168 , ..., 0.42961743, 1.6848629 ,
#          0.25942007], dtype=float32)},
#  994: {'p_id': 209,
#   'image_pth': '4a/4a664397.jpg',
#   'image_embedding': array([0.34897223, 0.45219484, 0.5163168 , ..., 0.42961743, 1.6848629 ,
#          0.25942007], dtype=float32)},
#  995: {'p_id': 210,
#   'image_pth': '1a/1a1401b7.jpg',
#   'image_embedding': array([0.09429407, 0.2434435 , 1.1388782 , ..., 0.09231688, 0.16239406,
#          0.1717469 ], dtype=float32)},
#  996: {'p_id': 211,
#   'image_pth': '46/462f9217.jpg',
#   'image_embedding': array([1.0294089 , 0.01406879, 0.02720144, ..., 0.04672087, 0.503894  ,
#          0.41261342], dtype=float32)},
#  997: {'p_id': 211,
#   'image_pth': '46/462f9217.jpg',
#   'image_embedding': array([1.0294089 , 0.01406879, 0.02720144, ..., 0.04672087, 0.503894  ,
#          0.41261342], dtype=float32)},
#  998: {'p_id': 211,
#   'image_pth': '46/462f9217.jpg',
#   'image_embedding': array([1.0294089 , 0.01406879, 0.02720144, ..., 0.04672087, 0.503894  ,
#          0.41261342], dtype=float32)},
#  999: {'p_id': 211,
#   'image_pth': '46/462f9217.jpg',
#   'image_embedding': array([1.0294089 , 0.01406879, 0.02720144, ..., 0.04672087, 0.503894  ,
#          0.41261342], dtype=float32)},
#  ...}

# %%
def ndarray_to_list(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    raise TypeError(f"Object of type {type(obj)} is not JSON serializable")

# %%
# Specify the file name
filename = 'updated_struct_jsons/intid_to_pdid_path_imageEmbed.json'

# Writing JSON data
with open(filename, 'w') as f:
    json.dump(id_to_pid_image_pth_embed, f, indent=4,default=ndarray_to_list)

# %%
def ndarray_to_list(obj):
    if isinstance(obj, np.ndarray):
        return obj.tolist()
    raise TypeError(f"Object of type {type(obj)} is not JSON serializable")

# %% [markdown]
# ## split jsons seperating embeddings

# %%
import json
def load_json(file_path):
    with open(file_path, 'r') as file:
        return json.load(file)

# %%
id_to_pid_image_pth_embed=load_json('updated_struct_jsons/intid_to_pdid_path_imageEmbed.json')

# %%
id_to_pid_image_pth_embed['0']
# Out:
# {'p_id': 0,
#  'image_pth': '66/665cc994.jpg',
#  'image_embedding': [0.08097482472658157,
#   0.4570974111557007,
#   0.0531173050403595,
#   0.31813111901283264,
#   0.666716456413269,
#   0.15806016325950623,
#   0.2719702124595642,
#   2.2316596508026123,
#   0.16540542244911194,
#   0.28136956691741943,
#   0.28358110785484314,
#   0.3700280487537384,
#   0.26680660247802734,
#   0.8432878851890564,
#   0.5482661128044128,
#   0.027355656027793884,
#   0.261583536863327,
#   0.5963881611824036,
#   0.19976291060447693,
#   0.2971297800540924,
#   0.08875595033168793,
#   0.2073967009782791,
#   0.23260557651519775,
#   0.03761221468448639,
#   0.25311943888664246,
#   0.0784093588590622,
#   0.3014521896839142,
#   0.07351474463939667,
#   0.25158318877220154,
#   0.03045313060283661,
#   0.4369363486766815,
#   0.12914496660232544,
#   0.609380304813385,
#   0.7463213205337524,
#   0.2784568667411804,
#   0.3815647065639496,
#   0.21033704280853271,
#   0.6072009801864624,
#   0.19017425179481506,
#   0.9396647214889526,
#   0.11234136670827866,
#   1.066356897354126,
#   0.2254970669746399,
#   0.749419093132019,
#   0.13374310731887817,
#   0.167620450258255,
#   0.29347556829452515,
#   0.11434196680784225,
#   0.06470590829849243,
#   0.2236306369304657,
#   1.1647645235061646,
#   0.08106741309165955,
#   0.5470702648162842,
#   0.35882988572120667,
#   0.09969181567430496,
#   0.3104383647441864,
#   0.24993926286697388,
#   0.6010030508041382,
#   0.050234027206897736,
#   0.36805060505867004,
#   0.15224187076091766,
#   0.32457616925239563,
#   0.2625964879989624,
#   0.8893771171569824,
#   0.8261507153511047,
#   0.16814492642879486,
#   1.2951431274414062,
#   0.37913477420806885,
#   0.14689132571220398,
#   0.15507902204990387,
#   0.8355245590209961,
#   0.040882859379053116,
#   0.8495725393295288,
#   0.49208107590675354,
#   0.3537471294403076,
#   1.1168900728225708,
#   0.43993479013442993,
#   0.2185233235359192,
#   0.1361709088087082,
#   0.1762750744819641,
#   0.6007283926010132,
#   0.055125586688518524,
#   0.28696808218955994,
#   0.5948341488838196,
#   0.2570422887802124,
#   0.0028192722238600254,
#   1.8714390993118286,
#   0.7216160297393799,
#   0.11305762082338333,
#   0.5511002540588379,
#   0.07322949916124344,
#   0.1191834807395935,
#   0.2020350694656372,
#   0.5216576457023621,
#   0.29492413997650146,
#   0.16980832815170288,
#   0.8653427362442017,
#   0.7956359386444092,
#   0.3030821681022644,
#   0.8919568061828613,
#   0.19746755063533783,
#   1.2033169269561768,
#   0.38355258107185364,
#   0.5392267107963562,
#   1.1543387174606323,
#   0.5010635256767273,
#   0.5658481121063232,
#   0.4155968129634857,
#   ...]}

# %%
id_to_img_embed={}

for key in id_to_pid_image_pth_embed:
    id_to_img_embed[key]=id_to_pid_image_pth_embed[key]['image_embedding']

# %%
filename = 'updated_struct_jsons/intid_to_imageEmbed.json'


with open(filename, 'w') as f:
    json.dump(id_to_img_embed, f, indent=4,default=ndarray_to_list)

# %%
del id_to_img_embed

# %%
id_to_pid_image_pth_embed['0'].keys()
# Out:
# dict_keys(['p_id', 'image_pth', 'image_embedding'])

# %%
id_to_img_paths_pid={}

for key in id_to_pid_image_pth_embed:
    id_to_img_paths_pid[key]={'p_id':id_to_pid_image_pth_embed[key]['p_id'], 'image_pth': id_to_pid_image_pth_embed[key]['image_pth']}

# %%
filename = 'updated_struct_jsons/intid_to_imagepth_pid.json'


with open(filename, 'w') as f:
    json.dump(id_to_img_paths_pid, f, indent=4,default=ndarray_to_list)
